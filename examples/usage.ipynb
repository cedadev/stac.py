# %% [markdown]
# # Usage
#
# ## Initialise Client
#
# Instantiate the STAC class with a valid STAC url endpoint.
#
# (Optional) Pass in any arguments needed to access the endpoint such as
# headers and verification.

# %%
import json
from stac.stac import STAC

url = 'https://api.stac.ceda.ac.uk'
Client = STAC(url=url, verify=False)

# %%
# Display function
def display(obj: dict):
    print(json.dumps(obj, indent=4))

# %% [markdown]
# ## Basic GET usages
#
# ### GET Collections
#
# **/collections**
#
# Retrieve a list of collections available at from the STAC endpoint.

# %%
collections = Client.collections
display(collections)
# Out:
# {
#     "Ca1oVHsBhuk7QqVbE5ej": {
#         "type": "Collection",
#         "id": "Ca1oVHsBhuk7QqVbE5ej",
#         "stac_extensions": [],
#         "stac_version": "1.0.0",
#         "title": "CMIP5",
#         "description": "The WCRP Coupled Model Intercomparison Project, Phase 5 (CMIP5), was a global climate model intercomparison project, coordinated by PCMDI (Program For Climate Model Diagnosis and Intercomparison) on behalf of the World Climate Research Program (WCRP) and provided input for the Intergovernmental Panel on Climate Change (IPCC) 5th Assessment Report (AR5).The CMIP5 archive is managed via the Earth System Grid Federation, a globally distributed archive, with various gateways with advanced faceted search capabilities provided by a number of participating organisations. Full details are available from the PCMDI CMIP5 pages (see linked documentation on this record).",
#         "keywords": [
#             "climate change",
#             "CMIP5",
#             "WCRP",
#             "CMIP"
#         ],
#         "license": " ",
#         "providers": null,
#         "summaries": {
#             "product": [
#                 "output1"
#             ],
#             "experiment": [
#                 "decadal1960"
#             ],
#             "time_frequency": [
#                 "mon"
#             ],
#             "variable": [
#                 "clt",
#                 "clt_20110627",
#                 "clt_20110825",
#                 "dryso2",
#                 "dryso2_20110627",
#                 "dryso2_20110825",
#                 "dryso4",
#                 "dryso4_20110627",
#                 "dryso4_20110825",
#                 "evspsbl",
#                 "evspsbl_20110627",
#                 "evspsbl_20110825",
#                 "evspsblveg",
#                 "evspsblveg_20110627",
#                 "evspsblveg_20110825",
#                 "gpp",
#                 "gpp_20110627",
#                 "gpp_20110825",
#                 "hfdsn",
#                 "hfdsn_20110627",
#                 "hfdsn_20110825",
#                 "hfls",
#                 "hfls_20110627",
#                 "hfls_20110825",
#                 "hfss",
#                 "hfss_20110627",
#                 "hfss_20110825",
#                 "hur",
#                 "hur_20110627",
#                 "hur_20110825",
#                 "hurs",
#                 "hurs_20110627",
#                 "hurs_20110825",
#                 "huss",
#                 "huss_20110627",
#                 "huss_20110825",
#                 "mrfso",
#                 "mrfso_20110627",
#                 "mrfso_20110825",
#                 "mrlsl",
#                 "mrlsl_20110627",
#                 "mrlsl_20110825",
#                 "mrro",
#                 "mrro_20110627",
#                 "mrro_20110825",
#                 "mrros",
#                 "mrros_20110627",
#                 "mrros_20110825",
#                 "mrso",
#                 "mrso_20110627",
#                 "mrso_20110825",
#                 "mrsos",
#                 "mrsos_20110627",
#                 "mrsos_20110825",
#                 "pr",
#                 "pr_20110627",
#                 "pr_20110825",
#                 "prc",
#                 "prc_20110627",
#                 "prc_20110825",
#                 "prsn",
#                 "prsn_20110627",
#                 "prsn_20110825",
#                 "prveg",
#                 "prveg_20110627",
#                 "prveg_20110825",
#                 "ps",
#                 "ps_20110627",
#                 "ps_20110825",
#                 "psl",
#                 "psl_20110627",
#                 "psl_20110825",
#                 "rlds",
#                 "rlds_20110627",
#                 "rlds_20110825",
#                 "rldscs",
#                 "rldscs_20110627",
#                 "rldscs_20110825",
#                 "rlus",
#                 "rlus_20110627",
#                 "rlus_20110825",
#                 "rlut",
#                 "rlut_20110627",
#                 "rlut_20110825",
#                 "rlutcs",
#                 "rlutcs_20110627",
#                 "rlutcs_20110825",
#                 "rsds",
#                 "rsds_20110627",
#                 "rsds_20110825",
#                 "rsdscs",
#                 "rsdscs_20110627",
#                 "rsdscs_20110825",
#                 "rsdt",
#                 "rsdt_20110627",
#                 "rsdt_20110825",
#                 "rsus",
#                 "rsus_20110627",
#                 "rsus_20110825",
#                 "rsuscs",
#                 "rsuscs_20110627",
#                 "rsuscs_20110825",
#                 "rsut",
#                 "rsut_20110627",
#                 "rsut_20110825",
#                 "rsutcs",
#                 "rsutcs_20110627",
#                 "rsutcs_20110825",
#                 "sbl",
#                 "sbl_20110627",
#                 "sbl_20110825",
#                 "sfcWind",
#                 "sfcWind_20110627",
#                 "sfcWind_20110825",
#                 "sic",
#                 "sic_20110627",
#                 "sic_20110825",
#                 "sit",
#                 "sit_20110627",
#                 "sit_20110825",
#                 "snm",
#                 "snm_20110627",
#                 "snm_20110825",
#                 "snw",
#                 "snw_20110627",
#                 "snw_20110825",
#                 "so",
#                 "so_20110627",
#                 "so_20110825",
#                 "sos",
#                 "sos_20110627",
#                 "sos_20110825",
#                 "ta",
#                 "ta_20110627",
#                 "ta_20110825",
#                 "tas",
#                 "tas_20110627",
#                 "tas_20110825",
#                 "tasmax",
#                 "tasmax_20110627",
#                 "tasmax_20110825",
#                 "tasmin",
#                 "tasmin_20110627",
#                 "tasmin_20110825",
#                 "tauu",
#                 "tauu_20110627",
#                 "tauu_20110825",
#                 "tauv",
#                 "tauv_20110627",
#                 "tauv_20110825",
#                 "thetao",
#                 "thetao_20110627",
#                 "thetao_20110825",
#                 "tos",
#                 "tos_20110627",
#                 "tos_20110825",
#                 "ts",
#                 "ts_20110627",
#                 "ts_20110825",
#                 "tsl",
#                 "tsl_20110627",
#                 "tsl_20110825",
#                 "ua",
#                 "ua_20110627",
#                 "ua_20110825",
#                 "uas",
#                 "uas_20110627",
#                 "uas_20110825",
#                 "uo",
#                 "uo_20110627",
#                 "uo_20110825",
#                 "va",
#                 "va_20110627",
#                 "va_20110825",
#                 "vas",
#                 "vas_20110627",
#                 "vas_20110825",
#                 "vo",
#                 "vo_20110627",
#                 "vo_20110825",
#                 "wap",
#                 "wap_20110627",
#                 "wap_20110825",
#                 "wetso2",
#                 "wetso2_20110627",
#                 "wetso2_20110825",
#                 "wetso4",
#                 "wetso4_20110627",
#                 "wetso4_20110825",
#                 "wfo",
#                 "wfo_20110627",
#                 "wfo_20110825",
#                 "zg",
#                 "zg_20110627",
#                 "zg_20110825"
#             ],
#             "institute": [
#                 "MOHC"
#             ],
#             "model": [
#                 "HadCM3"
#             ],
#             "realm": [
#                 "aerosol",
#                 "atmos",
#                 "land",
#                 "landIce",
#                 "ocean",
#                 "seaIce"
#             ],
#             "ensemble": [
#                 "r10i2p1",
#                 "r10i3p1",
#                 "r1i2p1",
#                 "r1i3p1",
#                 "r2i2p1",
#                 "r2i3p1",
#                 "r3i2p1",
#                 "r3i3p1",
#                 "r4i2p1",
#                 "r4i3p1",
#                 "r5i2p1",
#                 "r5i3p1",
#                 "r6i2p1",
#                 "r6i3p1",
#                 "r7i2p1",
#                 "r7i3p1",
#                 "r8i2p1",
#                 "r8i3p1",
#                 "r9i2p1",
#                 "r9i3p1"
#             ],
#             "cmip_table": [
#                 "Amon",
#                 "LImon",
#                 "Lmon",
#                 "OImon",
#                 "Omon",
#                 "aero"
#             ],
#             "version": [
#                 "files",
#                 "v20110627",
#                 "v20110825"
#             ]
#         },
#         "extent": {
#             "temporal": {
#                 "interval": [
#                     [
#                         "2016-01-01T00:00:00",
#                         "2100-12-31T23:59:59"
#                     ]
#                 ]
#             },
#             "spatial": {
#                 "bbox": [
#                     [
#                         -180,
#                         -90,
#                         180,
#                         90
#                     ]
#                 ]
#             }
#         },
#         "links": [
#             {
#                 "rel": "self",
#                 "type": "application/json",
#                 "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#             },
#             {
#                 "rel": "parent",
#                 "type": "application/json",
#                 "href": "https://api.stac.ceda.ac.uk/"
#             },
#             {
#                 "rel": "items",
#                 "type": "application/geo+json",
#                 "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej/items"
#             },
#             {
#                 "rel": "root",
#                 "type": "application/json",
#                 "href": "https://api.stac.ceda.ac.uk/"
#             },
#             {
#                 "rel": "http://www.opengis.net/def/rel/ogc/1.0/queryables",
#                 "type": "application/json",
#                 "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej/queryables"
#             }
#         ]
#     },
#     "WH5qEHoBZp5aDdjsfMv-": {
#         "type": "Collection",
#         "id": "WH5qEHoBZp5aDdjsfMv-",
#         "stac_extensions": [],
#         "stac_version": "1.0.0",
#         "title": "FAAM",
#         "description": "The FAAM is a large atmospheric research BAE-146 aircraft, run jointly by the NERC and the UK Met Office. It has been in operation since March 2004 and is at the scientists' disposal through a scheme of project selection. FAAM is the result of a collaboration between the Met Office(TM) and the Natural Environment Research Council (NERC) and has been established as part of the National Centre for Atmospheric Science (NCAS) to provide an aircraft measurement platform for use by all the UK atmospheric research community on campaigns throughout the world. The modified BAE 146 aircraft is owned by BAE Systems and operated for them by Directflight. The Home Base is at Cranfield University, Bedfordshire.",
#         "keywords": [
#             "RICO",
#             "FAAM",
#             "airborne",
#             "atmospheric measurements"
#         ],
#         "license": " ",
#         "providers": null,
#         "summaries": {
#             "flight_number": [
#                 "b069",
#                 "b070",
#                 "b071",
#                 "b072",
#                 "b073",
#                 "b074",
#                 "b075",
#                 "b076",
#                 "b077",
#                 "b078",
#                 "b079",
#                 "b080",
#                 "b081",
#                 "b082",
#                 "b083",
#                 "b084",
#                 "b085",
#                 "b086",
#                 "b087",
#                 "b088",
#                 "b089",
#                 "b090",
#                 "b091",
#                 "b092",
#                 "b093",
#                 "b094",
#                 "b095",
#                 "b096",
#                 "b097",
#                 "b098",
#                 "b099",
#                 "b100",
#                 "b101",
#                 "b102",
#                 "b103",
#                 "b104",
#                 "b105",
#                 "b106",
#                 "b107",
#                 "b108",
#                 "b109",
#                 "b110",
#                 "b111",
#                 "b112",
#                 "b113",
#                 "b114",
#                 "b115",
#                 "b116",
#                 "b117",
#                 "b118",
#                 "b119",
#                 "b120",
#                 "b121",
#                 "b122",
#                 "b123",
#                 "b124",
#                 "b125",
#                 "b126",
#                 "b127",
#                 "b128",
#                 "b129",
#                 "b130",
#                 "b131",
#                 "b132",
#                 "b133",
#                 "b134",
#                 "b135",
#                 "b136",
#                 "b137",
#                 "b138",
#                 "b139",
#                 "b140",
#                 "b141",
#                 "b142",
#                 "b143",
#                 "b144",
#                 "b145",
#                 "b146",
#                 "b147",
#                 "b148",
#                 "b149",
#                 "b150",
#                 "b151",
#                 "b152",
#                 "b153",
#                 "b154",
#                 "b155",
#                 "b156",
#                 "b157",
#                 "b158",
#                 "b159",
#                 "b160",
#                 "b161",
#                 "b162",
#                 "b163",
#                 "b164",
#                 "b165",
#                 "b166",
#                 "b167",
#                 "b168",
#                 "b169",
#                 "b170",
#                 "b171",
#                 "b172",
#                 "b173",
#                 "b174",
#                 "b175",
#                 "b176",
#                 "b177",
#                 "b178",
#                 "b179",
#                 "b180",
#                 "b181",
#                 "b182",
#                 "b183",
#                 "b184",
#                 "b185",
#                 "b186",
#                 "b187",
#                 "b188",
#                 "b189",
#                 "b190",
#                 "b191",
#                 "b192",
#                 "b193",
#                 "b194",
#                 "b195",
#                 "b196",
#                 "b197",
#                 "b198",
#                 "b199",
#                 "b200",
#                 "b201",
#                 "b202",
#                 "b203",
#                 "b204",
#                 "b205",
#                 "b206",
#                 "b207",
#                 "b208",
#                 "b209",
#                 "b210",
#                 "b211",
#                 "b212",
#                 "b213",
#                 "b214",
#                 "b215",
#                 "b216",
#                 "b217",
#                 "b218",
#                 "b219",
#                 "b220",
#                 "b221",
#                 "b222",
#                 "b223",
#                 "b224",
#                 "b225",
#                 "b226",
#                 "b227",
#                 "b228",
#                 "b229",
#                 "b230",
#                 "b231",
#                 "b232",
#                 "b233",
#                 "b234",
#                 "b235",
#                 "b236",
#                 "b237",
#                 "b238",
#                 "b239",
#                 "b240",
#                 "b241",
#                 "b242",
#                 "b243",
#                 "b244",
#                 "b245",
#                 "b246",
#                 "b247",
#                 "b248",
#                 "b249",
#                 "b250",
#                 "b251",
#                 "b252",
#                 "b253",
#                 "b254",
#                 "b255",
#                 "b256",
#                 "b257",
#                 "b258",
#                 "b259",
#                 "b260",
#                 "b261",
#                 "b262",
#                 "b263",
#                 "b264",
#                 "b265",
#                 "b266",
#                 "b267",
#                 "b268",
#                 "b269",
#                 "b270",
#                 "b271",
#                 "b272",
#                 "b273",
#                 "b274",
#                 "b275",
#                 "b276",
#                 "b277",
#                 "b278",
#                 "b279",
#                 "b280",
#                 "b281",
#                 "b282",
#                 "b283",
#                 "b284",
#                 "b285",
#                 "b286",
#                 "b287",
#                 "b288",
#                 "b289",
#                 "b290",
#                 "b291",
#                 "b292",
#                 "b293",
#                 "b294",
#                 "b295",
#                 "b296",
#                 "b297",
#                 "b298",
#                 "b299",
#                 "b300",
#                 "b301",
#                 "b302",
#                 "b303",
#                 "b304",
#                 "b305",
#                 "b306",
#                 "b307",
#                 "b308",
#                 "b309",
#                 "b310",
#                 "b311",
#                 "b312",
#                 "b313",
#                 "b314",
#                 "b315",
#                 "b316",
#                 "b317",
#                 "b318",
#                 "b319",
#                 "b320",
#                 "b321",
#                 "b322",
#                 "b323",
#                 "b324",
#                 "b325",
#                 "b326",
#                 "b327",
#                 "b328",
#                 "b329",
#                 "b330",
#                 "b331",
#                 "b332",
#                 "b333",
#                 "b334",
#                 "b335",
#                 "b336",
#                 "b337",
#                 "b338",
#                 "b339",
#                 "b340",
#                 "b341",
#                 "b342",
#                 "b343",
#                 "b344",
#                 "b345",
#                 "b346",
#                 "b347",
#                 "b348",
#                 "b349",
#                 "b350",
#                 "b351",
#                 "b352",
#                 "b353",
#                 "b354",
#                 "b355",
#                 "b356",
#                 "b357",
#                 "b358",
#                 "b359",
#                 "b360",
#                 "b361",
#                 "b362",
#                 "b363",
#                 "b364",
#                 "b365",
#                 "b366",
#                 "b367",
#                 "b368",
#                 "b369",
#                 "b370",
#                 "b371",
#                 "b372",
#                 "b373",
#                 "b374",
#                 "b375",
#                 "b376",
#                 "b377",
#                 "b378",
#                 "b379",
#                 "b380",
#                 "b381",
#                 "b382",
#                 "b383",
#                 "b384",
#                 "b385",
#                 "b386",
#                 "b387",
#                 "b388",
#                 "b389",
#                 "b390",
#                 "b391",
#                 "b392",
#                 "b393",
#                 "b394",
#                 "b395",
#                 "b396",
#                 "b397",
#                 "b398",
#                 "b399",
#                 "b400",
#                 "b401",
#                 "b402",
#                 "b403",
#                 "b404",
#                 "b405",
#                 "b406",
#                 "b407",
#                 "b408",
#                 "b409",
#                 "b410",
#                 "b411",
#                 "b412",
#                 "b413",
#                 "b414",
#                 "b415",
#                 "b416",
#                 "b417",
#                 "b418",
#                 "b419",
#                 "b420",
#                 "b421",
#                 "b422",
#                 "b423",
#                 "b424",
#                 "b425",
#                 "b426",
#                 "b427",
#                 "b428",
#                 "b429",
#                 "b430",
#                 "b431",
#                 "b432",
#                 "b433",
#                 "b434",
#                 "b435",
#                 "b436",
#                 "b437",
#                 "b438",
#                 "b439",
#                 "b440",
#                 "b441",
#                 "b442",
#                 "b443",
#                 "b444",
#                 "b445",
#                 "b446",
#                 "b447",
#                 "b448",
#                 "b449",
#                 "b450",
#                 "b451",
#                 "b452",
#                 "b453",
#                 "b454",
#                 "b455",
#                 "b456",
#                 "b457",
#                 "b458",
#                 "b459",
#                 "b460",
#                 "b461",
#                 "b462",
#                 "b463",
#                 "b464",
#                 "b465",
#                 "b466",
#                 "b467",
#                 "b468",
#                 "b469",
#                 "b470",
#                 "b471",
#                 "b472",
#                 "b473",
#                 "b474",
#                 "b475",
#                 "b476",
#                 "b477",
#                 "b478",
#                 "b479",
#                 "b480",
#                 "b481",
#                 "b482",
#                 "b483",
#                 "b484",
#                 "b485",
#                 "b486",
#                 "b487",
#                 "b488",
#                 "b489",
#                 "b490",
#                 "b491",
#                 "b492",
#                 "b493",
#                 "b494",
#                 "b495",
#                 "b496",
#                 "b497",
#                 "b498",
#                 "b499",
#                 "b500",
#                 "b501",
#                 "b502",
#                 "b503",
#                 "b504",
#                 "b505",
#                 "b506",
#                 "b507",
#                 "b508",
#                 "b509",
#                 "b510",
#                 "b511",
#                 "b512",
#                 "b513",
#                 "b514",
#                 "b515",
#                 "b516",
#                 "b517",
#                 "b518",
#                 "b519",
#                 "b520",
#                 "b521",
#                 "b522",
#                 "b523",
#                 "b524",
#                 "b525",
#                 "b526",
#                 "b527",
#                 "b528",
#                 "b529",
#                 "b530",
#                 "b531",
#                 "b532",
#                 "b533",
#                 "b534",
#                 "b535",
#                 "b536",
#                 "b537",
#                 "b538",
#                 "b539",
#                 "b540",
#                 "b541",
#                 "b542",
#                 "b543",
#                 "b544",
#                 "b545",
#                 "b546",
#                 "b547",
#                 "b548",
#                 "b549",
#                 "b550",
#                 "b551",
#                 "b552",
#                 "b553",
#                 "b554",
#                 "b555",
#                 "b556",
#                 "b557",
#                 "b558",
#                 "b559",
#                 "b560",
#                 "b561",
#                 "b562",
#                 "b563",
#                 "b564",
#                 "b565",
#                 "b566",
#                 "b567",
#                 "b568",
#                 "b569",
#                 "b570",
#                 "b571",
#                 "b572",
#                 "b573",
#                 "b574",
#                 "b575",
#                 "b576",
#                 "b577",
#                 "b578",
#                 "b579",
#                 "b580",
#                 "b581",
#                 "b582",
#                 "b583",
#                 "b584",
#                 "b585",
#                 "b586",
#                 "b587",
#                 "b588",
#                 "b589",
#                 "b590",
#                 "b591",
#                 "b592",
#                 "b593",
#                 "b594",
#                 "b595",
#                 "b596",
#                 "b597",
#                 "b598",
#                 "b599",
#                 "b600",
#                 "b601",
#                 "b602",
#                 "b603",
#                 "b604",
#                 "b605",
#                 "b606",
#                 "b607",
#                 "b608",
#                 "b609",
#                 "b610",
#                 "b611",
#                 "b612",
#                 "b613",
#                 "b614",
#                 "b615",
#                 "b616",
#                 "b617",
#                 "b618",
#                 "b619",
#                 "b620",
#                 "b621",
#                 "b622",
#                 "b623",
#                 "b624",
#                 "b625",
#                 "b626",
#                 "b627",
#                 "b628",
#                 "b629",
#                 "b630",
#                 "b631",
#                 "b632",
#                 "b633",
#                 "b634",
#                 "b635",
#                 "b636",
#                 "b637",
#                 "b638",
#                 "b639",
#                 "b640",
#                 "b641",
#                 "b642",
#                 "b643",
#                 "b644",
#                 "b645",
#                 "b646",
#                 "b647",
#                 "b648",
#                 "b649",
#                 "b650",
#                 "b651",
#                 "b652",
#                 "b653",
#                 "b654",
#                 "b655",
#                 "b656",
#                 "b657",
#                 "b658",
#                 "b659",
#                 "b660",
#                 "b661",
#                 "b662",
#                 "b663",
#                 "b664",
#                 "b665",
#                 "b666",
#                 "b667",
#                 "b668",
#                 "b669",
#                 "b670",
#                 "b671",
#                 "b672",
#                 "b673",
#                 "b674",
#                 "b675",
#                 "b676",
#                 "b677",
#                 "b678",
#                 "b679",
#                 "b680",
#                 "b681",
#                 "b682",
#                 "b683",
#                 "b684",
#                 "b685",
#                 "b686",
#                 "b687",
#                 "b688",
#                 "b689",
#                 "b690",
#                 "b691",
#                 "b692",
#                 "b693",
#                 "b694",
#                 "b695",
#                 "b696",
#                 "b697",
#                 "b698",
#                 "b699",
#                 "b700",
#                 "b701",
#                 "b702",
#                 "b703",
#                 "b704",
#                 "b705",
#                 "b706",
#                 "b707",
#                 "b708",
#                 "b709",
#                 "b710",
#                 "b711",
#                 "b712",
#                 "b713",
#                 "b714",
#                 "b715",
#                 "b716",
#                 "b717",
#                 "b718",
#                 "b719",
#                 "b720",
#                 "b721",
#                 "b722",
#                 "b723",
#                 "b724",
#                 "b725",
#                 "b726",
#                 "b727",
#                 "b728",
#                 "b729",
#                 "b730",
#                 "b731",
#                 "b732",
#                 "b733",
#                 "b734",
#                 "b735",
#                 "b736",
#                 "b737",
#                 "b738",
#                 "b739",
#                 "b740",
#                 "b741",
#                 "b742",
#                 "b743",
#                 "b744",
#                 "b745",
#                 "b746",
#                 "b747",
#                 "b748",
#                 "b749",
#                 "b750",
#                 "b751",
#                 "b752",
#                 "b753",
#                 "b754",
#                 "b755",
#                 "b756",
#                 "b757",
#                 "b758",
#                 "b759",
#                 "b760",
#                 "b761",
#                 "b762",
#                 "b763",
#                 "b764",
#                 "b765",
#                 "b766",
#                 "b767",
#                 "b768",
#                 "b769",
#                 "b770",
#                 "b771",
#                 "b772",
#                 "b773",
#                 "b774",
#                 "b775",
#                 "b776",
#                 "b777",
#                 "b778",
#                 "b779",
#                 "b780",
#                 "b781",
#                 "b782",
#                 "b783",
#                 "b784",
#                 "b785",
#                 "b786",
#                 "b787",
#                 "b788",
#                 "b789",
#                 "b790",
#                 "b791",
#                 "b792",
#                 "b793",
#                 "b794",
#                 "b795",
#                 "b796",
#                 "b797",
#                 "b798",
#                 "b799",
#                 "b800",
#                 "b801",
#                 "b802",
#                 "b803",
#                 "b804",
#                 "b805",
#                 "b806",
#                 "b807",
#                 "b808",
#                 "b809",
#                 "b810",
#                 "b811",
#                 "b812",
#                 "b813",
#                 "b814",
#                 "b815",
#                 "b816",
#                 "b817",
#                 "b818",
#                 "b819",
#                 "b820",
#                 "b821",
#                 "b822",
#                 "b823",
#                 "b824",
#                 "b825",
#                 "b826",
#                 "b827",
#                 "b828",
#                 "b829",
#                 "b830",
#                 "b831",
#                 "b832",
#                 "b833",
#                 "b834",
#                 "b835",
#                 "b836",
#                 "b837",
#                 "b838",
#                 "b839",
#                 "b840",
#                 "b841",
#                 "b842",
#                 "b843",
#                 "b844",
#                 "b845",
#                 "b846",
#                 "b847",
#                 "b848",
#                 "b849",
#                 "b850",
#                 "b851",
#                 "b852",
#                 "b853",
#                 "b854",
#                 "b855",
#                 "b856",
#                 "b857",
#                 "b858",
#                 "b859",
#                 "b860",
#                 "b861",
#                 "b862",
#                 "b863",
#                 "b864",
#                 "b865",
#                 "b866",
#                 "b867",
#                 "b868",
#                 "b869",
#                 "b870",
#                 "b871",
#                 "b872",
#                 "b873",
#                 "b874",
#                 "b875",
#                 "b876",
#                 "b877",
#                 "b878",
#                 "b879",
#                 "b880",
#                 "b881",
#                 "b882",
#                 "b883",
#                 "b884",
#                 "b885",
#                 "b886",
#                 "b887",
#                 "b888",
#                 "b889",
#                 "b890",
#                 "b891",
#                 "b892",
#                 "b893",
#                 "b894",
#                 "b895",
#                 "b896",
#                 "b897",
#                 "b898",
#                 "b899",
#                 "b900",
#                 "b901",
#                 "b902",
#                 "b903",
#                 "b904",
#                 "b905",
#                 "b906",
#                 "b907",
#                 "b908",
#                 "b909",
#                 "b910",
#                 "b911",
#                 "b912",
#                 "b913",
#                 "b914",
#                 "b915",
#                 "b916",
#                 "b917",
#                 "b918",
#                 "b919",
#                 "b920",
#                 "b921",
#                 "b922",
#                 "b923",
#                 "b924",
#                 "b925",
#                 "b926",
#                 "b927",
#                 "b928",
#                 "b929",
#                 "b930",
#                 "b931",
#                 "b932",
#                 "b933",
#                 "b934",
#                 "b935",
#                 "b936",
#                 "b937",
#                 "b938",
#                 "b939",
#                 "b940",
#                 "b941",
#                 "b942",
#                 "b943",
#                 "b944",
#                 "b945",
#                 "b946",
#                 "b947",
#                 "b948",
#                 "b949",
#                 "b950",
#                 "b951",
#                 "b952",
#                 "b953",
#                 "b954",
#                 "b955",
#                 "b956",
#                 "b957",
#                 "b958",
#                 "b959",
#                 "b960",
#                 "b961",
#                 "b962",
#                 "b963",
#                 "b964",
#                 "b965",
#                 "b966",
#                 "b967",
#                 "b968",
#                 "b969",
#                 "b970",
#                 "b971",
#                 "b972",
#                 "b973",
#                 "b974",
#                 "b975",
#                 "b976",
#                 "b977",
#                 "b978",
#                 "b979",
#                 "b980",
#                 "b981",
#                 "b982",
#                 "b983",
#                 "b984",
#                 "b985",
#                 "b986",
#                 "b987",
#                 "b988",
#                 "b989",
#                 "b990",
#                 "b991",
#                 "b992",
#                 "b993",
#                 "b994",
#                 "b995",
#                 "b996",
#                 "b997",
#                 "b998",
#                 "b999",
#                 "c001",
#                 "c002",
#                 "c003",
#                 "c004",
#                 "c005",
#                 "c006",
#                 "c007",
#                 "c008",
#                 "c009",
#                 "c010",
#                 "c011",
#                 "c012",
#                 "c013",
#                 "c014",
#                 "c015",
#                 "c016",
#                 "c017",
#                 "c018",
#                 "c019",
#                 "c020",
#                 "c021",
#                 "c022",
#                 "c023",
#                 "c024",
#                 "c025",
#                 "c026",
#                 "c027",
#                 "c028",
#                 "c029",
#                 "c030",
#                 "c031",
#                 "c032",
#                 "c033",
#                 "c034",
#                 "c035",
#                 "c036",
#                 "c037",
#                 "c038",
#                 "c039",
#                 "c040",
#                 "c041",
#                 "c042",
#                 "c043",
#                 "c044",
#                 "c045",
#                 "c046",
#                 "c047",
#                 "c048",
#                 "c049",
#                 "c050",
#                 "c051",
#                 "c052",
#                 "c053",
#                 "c054",
#                 "c055",
#                 "c056",
#                 "c057",
#                 "c058",
#                 "c059",
#                 "c060",
#                 "c061",
#                 "c062",
#                 "c063",
#                 "c064",
#                 "c065",
#                 "c066",
#                 "c067",
#                 "c068",
#                 "c069",
#                 "c070",
#                 "c071",
#                 "c072",
#                 "c073",
#                 "c074",
#                 "c075",
#                 "c076",
#                 "c077",
#                 "c078",
#                 "c079",
#                 "c080",
#                 "c081",
#                 "c082",
#                 "c083",
#                 "c084",
#                 "c085",
#                 "c086",
#                 "c087",
#                 "c088",
#                 "c089",
#                 "c090",
#                 "c091",
#                 "c092",
#                 "c093",
#                 "c094",
#                 "c095",
#                 "c096",
#                 "c097",
#                 "c098",
#                 "c099",
#                 "c100",
#                 "c101",
#                 "c102",
#                 "c103",
#                 "c104",
#                 "c105",
#                 "c106",
#                 "c107",
#                 "c108",
#                 "c109",
#                 "c110",
#                 "c111",
#                 "c112",
#                 "c113",
#                 "c114",
#                 "c115",
#                 "c116",
#                 "c117",
#                 "c118",
#                 "c119",
#                 "c120",
#                 "c121",
#                 "c122",
#                 "c123",
#                 "c124",
#                 "c125",
#                 "c126",
#                 "c127",
#                 "c128",
#                 "c129",
#                 "c130",
#                 "c131",
#                 "c132",
#                 "c133",
#                 "c134",
#                 "c135",
#                 "c136",
#                 "c137",
#                 "c138",
#                 "c139",
#                 "c140",
#                 "c141",
#                 "c142",
#                 "c143",
#                 "c144",
#                 "c145",
#                 "c146",
#                 "c147",
#                 "c148",
#                 "c149",
#                 "c150",
#                 "c151",
#                 "c152",
#                 "c153",
#                 "c154",
#                 "c155",
#                 "c156",
#                 "c157",
#                 "c158",
#                 "c159",
#                 "c160",
#                 "c161",
#                 "c162",
#                 "c163",
#                 "c164",
#                 "c165",
#                 "c166",
#                 "c167",
#                 "c168",
#                 "c169",
#                 "c170",
#                 "c171",
#                 "c172",
#                 "c173",
#                 "c174",
#                 "c175",
#                 "c176",
#                 "c177",
#                 "c178",
#                 "c179",
#                 "c180",
#                 "c181",
#                 "c182",
#                 "c183",
#                 "c184",
#                 "c185",
#                 "c186",
#                 "c187",
#                 "c188",
#                 "c189",
#                 "c190",
#                 "c191",
#                 "c192",
#                 "c193",
#                 "c194",
#                 "c195",
#                 "c196",
#                 "c197",
#                 "c198",
#                 "c199",
#                 "c200",
#                 "c201",
#                 "c202",
#                 "c203",
#                 "c204",
#                 "c205",
#                 "c206",
#                 "c207",
#                 "c208",
#                 "c209",
#                 "c210",
#                 "c211",
#                 "c212",
#                 "c213",
#                 "c214",
#                 "c215",
#                 "c216",
#                 "c217",
#                 "c218",
#                 "c219",
#                 "c220",
#                 "c221",
#                 "c222",
#                 "c223",
#                 "c224",
#                 "c225",
#                 "c226",
#                 "c227",
#                 "c228",
#                 "c229",
#                 "c230",
#                 "c231",
#                 "c232",
#                 "c233",
#                 "c234",
#                 "c235",
#                 "c236",
#                 "c237",
#                 "c238",
#                 "c239",
#                 "c240",
#                 "c241",
#                 "c242",
#                 "c243",
#                 "c244",
#                 "c245",
#                 "c246"
#             ],
#             "platform": [
#                 "faam"
#             ]
#         },
#         "extent": {
#             "temporal": {
#                 "interval": [
#                     [
#                         "2005-01-05T00:00:00+00:00",
#                         "2021-07-14T00:00:00+00:00"
#                     ]
#                 ]
#             },
#             "spatial": {
#                 "bbox": [
#                     [
#                         -28.7914,
#                         38.4686,
#                         -0.61,
#                         52.079
#                     ]
#                 ]
#             }
#         },
#         "links": [
#             {
#                 "rel": "self",
#                 "type": "application/json",
#                 "href": "https://api.stac.ceda.ac.uk/collections/WH5qEHoBZp5aDdjsfMv-"
#             },
#             {
#                 "rel": "parent",
#                 "type": "application/json",
#                 "href": "https://api.stac.ceda.ac.uk/"
#             },
#             {
#                 "rel": "items",
#                 "type": "application/geo+json",
#                 "href": "https://api.stac.ceda.ac.uk/collections/WH5qEHoBZp5aDdjsfMv-/items"
#             },
#             {
#                 "rel": "root",
#                 "type": "application/json",
#                 "href": "https://api.stac.ceda.ac.uk/"
#             },
#             {
#                 "rel": "http://www.opengis.net/def/rel/ogc/1.0/queryables",
#                 "type": "application/json",
#                 "href": "https://api.stac.ceda.ac.uk/collections/WH5qEHoBZp5aDdjsfMv-/queryables"
#             }
#         ]
#     },
#     "Ic93XnsBhuk7QqVbSFwS": {
#         "type": "Collection",
#         "id": "Ic93XnsBhuk7QqVbSFwS",
#         "stac_extensions": [],
#         "stac_version": "1.0.0",
#         "title": "Sentinel 5",
#         "description": "Sentinel-5 Precursor \u2013 also known as Sentinel-5P \u2013 is the first Copernicus mission dedicated to monitoring our atmosphere. The satellite carries the state-of-the-art Tropomi instrument to map a multitude of trace gases, which affect the air we breathe and therefore our health, and our climate.",
#         "keywords": [
#             "sentinel"
#         ],
#         "license": " ",
#         "providers": null,
#         "summaries": {
#             "product_version": [
#                 "v1.3",
#                 "v1.4"
#             ],
#             "processing_level": [
#                 "L2"
#             ],
#             "variable": [
#                 "CH4"
#             ],
#             "platform": [
#                 "sentinel5p"
#             ]
#         },
#         "extent": {
#             "temporal": {
#                 "interval": [
#                     [
#                         "2019-03-20T17:35:42+00:00",
#                         "2020-11-29T23:49:26+00:00"
#                     ]
#                 ]
#             },
#             "spatial": {
#                 "bbox": [
#                     [
#                         -180,
#                         -90,
#                         180,
#                         90
#                     ]
#                 ]
#             }
#         },
#         "links": [
#             {
#                 "rel": "self",
#                 "type": "application/json",
#                 "href": "https://api.stac.ceda.ac.uk/collections/Ic93XnsBhuk7QqVbSFwS"
#             },
#             {
#                 "rel": "parent",
#                 "type": "application/json",
#                 "href": "https://api.stac.ceda.ac.uk/"
#             },
#             {
#                 "rel": "items",
#                 "type": "application/geo+json",
#                 "href": "https://api.stac.ceda.ac.uk/collections/Ic93XnsBhuk7QqVbSFwS/items"
#             },
#             {
#                 "rel": "root",
#                 "type": "application/json",
#                 "href": "https://api.stac.ceda.ac.uk/"
#             },
#             {
#                 "rel": "http://www.opengis.net/def/rel/ogc/1.0/queryables",
#                 "type": "application/json",
#                 "href": "https://api.stac.ceda.ac.uk/collections/Ic93XnsBhuk7QqVbSFwS/queryables"
#             }
#         ]
#     },
#     "wiLHc3sBhuk7QqVbjTmQ": {
#         "type": "Collection",
#         "id": "wiLHc3sBhuk7QqVbjTmQ",
#         "stac_extensions": [],
#         "stac_version": "1.0.0",
#         "title": "Sentinel 1",
#         "description": "Sentinel 1 is the first of the European Space Agency (ESA) Sentinel series.",
#         "keywords": [
#             "sentinel"
#         ],
#         "license": " ",
#         "providers": null,
#         "summaries": {
#             "product_version": [
#                 "v2"
#             ],
#             "product_type": [
#                 "SLC"
#             ],
#             "processing_level": [
#                 "L1"
#             ],
#             "platform": [
#                 "sentinel1a"
#             ],
#             "instrument_mode": [
#                 "IW"
#             ]
#         },
#         "extent": {
#             "temporal": {
#                 "interval": [
#                     [
#                         "2014-10-03T05:42:35+00:00",
#                         "2014-10-03T16:51:46+00:00"
#                     ]
#                 ]
#             },
#             "spatial": {
#                 "bbox": [
#                     [
#                         -180,
#                         -90,
#                         180,
#                         90
#                     ]
#                 ]
#             }
#         },
#         "links": [
#             {
#                 "rel": "self",
#                 "type": "application/json",
#                 "href": "https://api.stac.ceda.ac.uk/collections/wiLHc3sBhuk7QqVbjTmQ"
#             },
#             {
#                 "rel": "parent",
#                 "type": "application/json",
#                 "href": "https://api.stac.ceda.ac.uk/"
#             },
#             {
#                 "rel": "items",
#                 "type": "application/geo+json",
#                 "href": "https://api.stac.ceda.ac.uk/collections/wiLHc3sBhuk7QqVbjTmQ/items"
#             },
#             {
#                 "rel": "root",
#                 "type": "application/json",
#                 "href": "https://api.stac.ceda.ac.uk/"
#             },
#             {
#                 "rel": "http://www.opengis.net/def/rel/ogc/1.0/queryables",
#                 "type": "application/json",
#                 "href": "https://api.stac.ceda.ac.uk/collections/wiLHc3sBhuk7QqVbjTmQ/queryables"
#             }
#         ]
#     },
#     "zwE8GHwBstFSrDJeqxf4": {
#         "type": "Collection",
#         "id": "zwE8GHwBstFSrDJeqxf4",
#         "stac_extensions": [],
#         "stac_version": "1.0.0",
#         "title": "MODIS",
#         "description": "Data products from the Moderate Resolution Imaging Spectroradiometer (MODIS) instrument onboard the Terra and Aqua satellites as part of NASA-led international Earth Observation System (EOS) programme. MODIS provides high radiometric sensitivity (12 bit) in 36 spectral bands ranging in wavelength from 0.4 micrometres to 14.4 micrometres. Two bands are imaged at a nominal resolution of 250 m at nadir, with five bands at 500 m, and the remaining 29 bands at 1 km. A +/- 55-degree scanning pattern at the EOS orbit of 705 km achieves a 2,330-km swath and provides global coverage every one to two days. The main objective of MODIS is to enhance our understandings on global dynamics and processes occurring on the land, in the oceans and in the lower atmosphere, and these data are also essential in the development of validated, global and interactive Earth system models.",
#         "keywords": [],
#         "license": " ",
#         "providers": null,
#         "summaries": null,
#         "extent": {
#             "temporal": {
#                 "interval": [
#                     [
#                         "2000-02-23T23:55:00",
#                         null
#                     ]
#                 ]
#             },
#             "spatial": {
#                 "bbox": [
#                     [
#                         -180,
#                         -90,
#                         180,
#                         90
#                     ]
#                 ]
#             }
#         },
#         "links": [
#             {
#                 "rel": "self",
#                 "type": "application/json",
#                 "href": "https://api.stac.ceda.ac.uk/collections/zwE8GHwBstFSrDJeqxf4"
#             },
#             {
#                 "rel": "parent",
#                 "type": "application/json",
#                 "href": "https://api.stac.ceda.ac.uk/"
#             },
#             {
#                 "rel": "items",
#                 "type": "application/geo+json",
#                 "href": "https://api.stac.ceda.ac.uk/collections/zwE8GHwBstFSrDJeqxf4/items"
#             },
#             {
#                 "rel": "root",
#                 "type": "application/json",
#                 "href": "https://api.stac.ceda.ac.uk/"
#             },
#             {
#                 "rel": "http://www.opengis.net/def/rel/ogc/1.0/queryables",
#                 "type": "application/json",
#                 "href": "https://api.stac.ceda.ac.uk/collections/zwE8GHwBstFSrDJeqxf4/queryables"
#             }
#         ]
#     },
#     "Fj3reHsBhuk7QqVbt7P-": {
#         "type": "Collection",
#         "id": "Fj3reHsBhuk7QqVbt7P-",
#         "stac_extensions": [],
#         "stac_version": "1.0.0",
#         "title": "CMIP6",
#         "description": "The WCRP Coupled Model Intercomparison Project, Phase 6 (CMIP6), is a global climate model intercomparison project, coordinated by PCMDI (Program For Climate Model Diagnosis and Intercomparison) on behalf of the World Climate Research Program (WCRP) providing input for the Intergovernmental Panel on Climate Change (IPCC) 6th Assessment Report (AR6).The CMIP6 archive is managed via the Earth System Grid Federation, a globally distributed archive, with various portals delivering advanced faceted search capabilities provided from a number of participating organisations. Full details are available from the CMIP6 pages (see linked documentation on this record).CEDA provides access to key CMIP6 simulations including those generated by the UK CMIP6 collaboration between the Met Office and NERC. Replicas of international data sets are provided to aid local access and use.",
#         "keywords": [
#             "MIP",
#             "CMIP",
#             "CMIP6",
#             "WCRP",
#             "climate change",
#             "IPCC",
#             "climate",
#             "model",
#             "simulation",
#             "multi-model"
#         ],
#         "license": " ",
#         "providers": null,
#         "summaries": {
#             "mip_era": [
#                 "CMIP6"
#             ],
#             "activity_id": [
#                 "AerChemMIP",
#                 "CDRMIP",
#                 "FAFMIP"
#             ],
#             "source_id": [
#                 "ACCESS-ESM1-5",
#                 "CNRM-ESM2-1",
#                 "MPI-ESM1-2-HR"
#             ],
#             "table_id": [
#                 "3hr",
#                 "6hrPlevPt",
#                 "Amon",
#                 "CF3hr",
#                 "Eday",
#                 "Lmon",
#                 "Oday",
#                 "Ofx",
#                 "Omon",
#                 "fx"
#             ],
#             "institution_id": [
#                 "CNRM-CERFACS",
#                 "CSIRO",
#                 "MPI-M"
#             ],
#             "var_id": [
#                 "baresoilFrac",
#                 "basin",
#                 "cVeg",
#                 "ch4",
#                 "clivi",
#                 "clt",
#                 "clwvi",
#                 "co2",
#                 "cropFrac",
#                 "deptho",
#                 "evspsbl",
#                 "fgco2",
#                 "gpp",
#                 "grassFrac",
#                 "hfds",
#                 "hfls",
#                 "hfss",
#                 "hur",
#                 "hus",
#                 "lai",
#                 "masscello",
#                 "masso",
#                 "mlotst",
#                 "mrro",
#                 "mrso",
#                 "mrsos",
#                 "msftbarot",
#                 "msftmz",
#                 "nbp",
#                 "o2",
#                 "o3",
#                 "orog",
#                 "pr",
#                 "prsn",
#                 "prw",
#                 "ps",
#                 "psl",
#                 "rlds",
#                 "rldscs",
#                 "rlut",
#                 "rlutcs",
#                 "rsds",
#                 "rsdscs",
#                 "rsut",
#                 "rsutcs",
#                 "sftlf",
#                 "sftof",
#                 "so",
#                 "sos",
#                 "spco2",
#                 "ta",
#                 "talk",
#                 "tas",
#                 "tasmax",
#                 "tasmin",
#                 "tauu",
#                 "tauuo",
#                 "tauv",
#                 "tauvo",
#                 "thetao",
#                 "thkcello",
#                 "tos",
#                 "treeFrac",
#                 "ts",
#                 "ua",
#                 "umo",
#                 "uo",
#                 "va",
#                 "vmo",
#                 "vo",
#                 "volcello",
#                 "volo",
#                 "wap",
#                 "zg",
#                 "zos"
#             ],
#             "version": [
#                 "20190621",
#                 "20191119",
#                 "20191231"
#             ]
#         },
#         "extent": {
#             "temporal": {
#                 "interval": [
#                     [
#                         "1950-01-01T00:00:00+00:00",
#                         "2014-12-01T00:00:00+00:00"
#                     ]
#                 ]
#             },
#             "spatial": {
#                 "bbox": [
#                     [
#                         -180,
#                         -90,
#                         180,
#                         90
#                     ]
#                 ]
#             }
#         },
#         "links": [
#             {
#                 "rel": "self",
#                 "type": "application/json",
#                 "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#             },
#             {
#                 "rel": "parent",
#                 "type": "application/json",
#                 "href": "https://api.stac.ceda.ac.uk/"
#             },
#             {
#                 "rel": "items",
#                 "type": "application/geo+json",
#                 "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-/items"
#             },
#             {
#                 "rel": "root",
#                 "type": "application/json",
#                 "href": "https://api.stac.ceda.ac.uk/"
#             },
#             {
#                 "rel": "http://www.opengis.net/def/rel/ogc/1.0/queryables",
#                 "type": "application/json",
#                 "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-/queryables"
#             }
#         ]
#     }
# }
# /Users/kazi.mahir/python-virtual-environments/stac/lib/python3.9/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.stac.ceda.ac.uk'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %% [markdown]
# ### GET Collection
#
# **/collections/{collectionId}**
#
# Retreive a collection, given a collection ID, from the STAC endpoint.

# %%
collection_id = Client.catalog[0]
collection = Client.collection(collection_id)
display(collection)
# Out:
# /Users/kazi.mahir/python-virtual-environments/stac/lib/python3.9/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.stac.ceda.ac.uk'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# {
#     "type": "Collection",
#     "id": "Ca1oVHsBhuk7QqVbE5ej",
#     "stac_extensions": [],
#     "stac_version": "1.0.0",
#     "title": "CMIP5",
#     "description": "The WCRP Coupled Model Intercomparison Project, Phase 5 (CMIP5), was a global climate model intercomparison project, coordinated by PCMDI (Program For Climate Model Diagnosis and Intercomparison) on behalf of the World Climate Research Program (WCRP) and provided input for the Intergovernmental Panel on Climate Change (IPCC) 5th Assessment Report (AR5).The CMIP5 archive is managed via the Earth System Grid Federation, a globally distributed archive, with various gateways with advanced faceted search capabilities provided by a number of participating organisations. Full details are available from the PCMDI CMIP5 pages (see linked documentation on this record).",
#     "keywords": [
#         "climate change",
#         "CMIP5",
#         "WCRP",
#         "CMIP"
#     ],
#     "license": " ",
#     "providers": null,
#     "summaries": {
#         "product": [
#             "output1"
#         ],
#         "experiment": [
#             "decadal1960"
#         ],
#         "time_frequency": [
#             "mon"
#         ],
#         "variable": [
#             "clt",
#             "clt_20110627",
#             "clt_20110825",
#             "dryso2",
#             "dryso2_20110627",
#             "dryso2_20110825",
#             "dryso4",
#             "dryso4_20110627",
#             "dryso4_20110825",
#             "evspsbl",
#             "evspsbl_20110627",
#             "evspsbl_20110825",
#             "evspsblveg",
#             "evspsblveg_20110627",
#             "evspsblveg_20110825",
#             "gpp",
#             "gpp_20110627",
#             "gpp_20110825",
#             "hfdsn",
#             "hfdsn_20110627",
#             "hfdsn_20110825",
#             "hfls",
#             "hfls_20110627",
#             "hfls_20110825",
#             "hfss",
#             "hfss_20110627",
#             "hfss_20110825",
#             "hur",
#             "hur_20110627",
#             "hur_20110825",
#             "hurs",
#             "hurs_20110627",
#             "hurs_20110825",
#             "huss",
#             "huss_20110627",
#             "huss_20110825",
#             "mrfso",
#             "mrfso_20110627",
#             "mrfso_20110825",
#             "mrlsl",
#             "mrlsl_20110627",
#             "mrlsl_20110825",
#             "mrro",
#             "mrro_20110627",
#             "mrro_20110825",
#             "mrros",
#             "mrros_20110627",
#             "mrros_20110825",
#             "mrso",
#             "mrso_20110627",
#             "mrso_20110825",
#             "mrsos",
#             "mrsos_20110627",
#             "mrsos_20110825",
#             "pr",
#             "pr_20110627",
#             "pr_20110825",
#             "prc",
#             "prc_20110627",
#             "prc_20110825",
#             "prsn",
#             "prsn_20110627",
#             "prsn_20110825",
#             "prveg",
#             "prveg_20110627",
#             "prveg_20110825",
#             "ps",
#             "ps_20110627",
#             "ps_20110825",
#             "psl",
#             "psl_20110627",
#             "psl_20110825",
#             "rlds",
#             "rlds_20110627",
#             "rlds_20110825",
#             "rldscs",
#             "rldscs_20110627",
#             "rldscs_20110825",
#             "rlus",
#             "rlus_20110627",
#             "rlus_20110825",
#             "rlut",
#             "rlut_20110627",
#             "rlut_20110825",
#             "rlutcs",
#             "rlutcs_20110627",
#             "rlutcs_20110825",
#             "rsds",
#             "rsds_20110627",
#             "rsds_20110825",
#             "rsdscs",
#             "rsdscs_20110627",
#             "rsdscs_20110825",
#             "rsdt",
#             "rsdt_20110627",
#             "rsdt_20110825",
#             "rsus",
#             "rsus_20110627",
#             "rsus_20110825",
#             "rsuscs",
#             "rsuscs_20110627",
#             "rsuscs_20110825",
#             "rsut",
#             "rsut_20110627",
#             "rsut_20110825",
#             "rsutcs",
#             "rsutcs_20110627",
#             "rsutcs_20110825",
#             "sbl",
#             "sbl_20110627",
#             "sbl_20110825",
#             "sfcWind",
#             "sfcWind_20110627",
#             "sfcWind_20110825",
#             "sic",
#             "sic_20110627",
#             "sic_20110825",
#             "sit",
#             "sit_20110627",
#             "sit_20110825",
#             "snm",
#             "snm_20110627",
#             "snm_20110825",
#             "snw",
#             "snw_20110627",
#             "snw_20110825",
#             "so",
#             "so_20110627",
#             "so_20110825",
#             "sos",
#             "sos_20110627",
#             "sos_20110825",
#             "ta",
#             "ta_20110627",
#             "ta_20110825",
#             "tas",
#             "tas_20110627",
#             "tas_20110825",
#             "tasmax",
#             "tasmax_20110627",
#             "tasmax_20110825",
#             "tasmin",
#             "tasmin_20110627",
#             "tasmin_20110825",
#             "tauu",
#             "tauu_20110627",
#             "tauu_20110825",
#             "tauv",
#             "tauv_20110627",
#             "tauv_20110825",
#             "thetao",
#             "thetao_20110627",
#             "thetao_20110825",
#             "tos",
#             "tos_20110627",
#             "tos_20110825",
#             "ts",
#             "ts_20110627",
#             "ts_20110825",
#             "tsl",
#             "tsl_20110627",
#             "tsl_20110825",
#             "ua",
#             "ua_20110627",
#             "ua_20110825",
#             "uas",
#             "uas_20110627",
#             "uas_20110825",
#             "uo",
#             "uo_20110627",
#             "uo_20110825",
#             "va",
#             "va_20110627",
#             "va_20110825",
#             "vas",
#             "vas_20110627",
#             "vas_20110825",
#             "vo",
#             "vo_20110627",
#             "vo_20110825",
#             "wap",
#             "wap_20110627",
#             "wap_20110825",
#             "wetso2",
#             "wetso2_20110627",
#             "wetso2_20110825",
#             "wetso4",
#             "wetso4_20110627",
#             "wetso4_20110825",
#             "wfo",
#             "wfo_20110627",
#             "wfo_20110825",
#             "zg",
#             "zg_20110627",
#             "zg_20110825"
#         ],
#         "institute": [
#             "MOHC"
#         ],
#         "model": [
#             "HadCM3"
#         ],
#         "realm": [
#             "aerosol",
#             "atmos",
#             "land",
#             "landIce",
#             "ocean",
#             "seaIce"
#         ],
#         "ensemble": [
#             "r10i2p1",
#             "r10i3p1",
#             "r1i2p1",
#             "r1i3p1",
#             "r2i2p1",
#             "r2i3p1",
#             "r3i2p1",
#             "r3i3p1",
#             "r4i2p1",
#             "r4i3p1",
#             "r5i2p1",
#             "r5i3p1",
#             "r6i2p1",
#             "r6i3p1",
#             "r7i2p1",
#             "r7i3p1",
#             "r8i2p1",
#             "r8i3p1",
#             "r9i2p1",
#             "r9i3p1"
#         ],
#         "cmip_table": [
#             "Amon",
#             "LImon",
#             "Lmon",
#             "OImon",
#             "Omon",
#             "aero"
#         ],
#         "version": [
#             "files",
#             "v20110627",
#             "v20110825"
#         ]
#     },
#     "extent": {
#         "temporal": {
#             "interval": [
#                 [
#                     "2016-01-01T00:00:00",
#                     "2100-12-31T23:59:59"
#                 ]
#             ]
#         },
#         "spatial": {
#             "bbox": [
#                 [
#                     -180,
#                     -90,
#                     180,
#                     90
#                 ]
#             ]
#         }
#     },
#     "links": [
#         {
#             "rel": "self",
#             "type": "application/json",
#             "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#         },
#         {
#             "rel": "parent",
#             "type": "application/json",
#             "href": "https://api.stac.ceda.ac.uk/"
#         },
#         {
#             "rel": "items",
#             "type": "application/geo+json",
#             "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej/items"
#         },
#         {
#             "rel": "root",
#             "type": "application/json",
#             "href": "https://api.stac.ceda.ac.uk/"
#         },
#         {
#             "rel": "http://www.opengis.net/def/rel/ogc/1.0/queryables",
#             "type": "application/json",
#             "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej/queryables"
#         }
#     ]
# }
# /Users/kazi.mahir/python-virtual-environments/stac/lib/python3.9/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.stac.ceda.ac.uk'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %% [markdown]
# ### GET Itemcollection
#
# **/collections/{collectionId}/items**
#
# Retrieve a list of items of a specific collection.

# %%
items = collection.get_items()
display(items)
# Out:
# /Users/kazi.mahir/python-virtual-environments/stac/lib/python3.9/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.stac.ceda.ac.uk'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# {
#     "type": "FeatureCollection",
#     "features": [
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "7b7f9b274fb11aa835699556b238a407",
#             "collection": "Ca1oVHsBhuk7QqVbE5ej",
#             "bbox": null,
#             "properties": {
#                 "datacentre": "BADC",
#                 "platform": "cmip5",
#                 "product": "output1",
#                 "institute": "MOHC",
#                 "model": "HadCM3",
#                 "experiment": "decadal1960",
#                 "time_frequency": "mon",
#                 "realm": "atmos",
#                 "cmip_table": "Amon",
#                 "ensemble": "r10i2p1",
#                 "version": "files",
#                 "variable": "clt_20110627"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej/items/7b7f9b274fb11aa835699556b238a407"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "7b7f9b274fb11aa835699556b238a407": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip5/data/cmip5/output1/MOHC/HadCM3/decadal1960/mon/atmos/Amon/r10i2p1/files/clt_20110627/clt_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "type": "application/octet-stream",
#                     "title": "clt_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "9fe215254c4be9b50c117fe799309f63",
#             "collection": "Ca1oVHsBhuk7QqVbE5ej",
#             "bbox": null,
#             "properties": {
#                 "datacentre": "BADC",
#                 "platform": "cmip5",
#                 "product": "output1",
#                 "institute": "MOHC",
#                 "model": "HadCM3",
#                 "experiment": "decadal1960",
#                 "time_frequency": "mon",
#                 "realm": "atmos",
#                 "cmip_table": "Amon",
#                 "ensemble": "r10i2p1",
#                 "version": "files",
#                 "variable": "evspsbl_20110627"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej/items/9fe215254c4be9b50c117fe799309f63"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "9fe215254c4be9b50c117fe799309f63": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip5/data/cmip5/output1/MOHC/HadCM3/decadal1960/mon/atmos/Amon/r10i2p1/files/evspsbl_20110627/evspsbl_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "type": "application/octet-stream",
#                     "title": "evspsbl_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "dedf8eba79d33915098b5be54a3fab71",
#             "collection": "Ca1oVHsBhuk7QqVbE5ej",
#             "bbox": null,
#             "properties": {
#                 "datacentre": "BADC",
#                 "platform": "cmip5",
#                 "product": "output1",
#                 "institute": "MOHC",
#                 "model": "HadCM3",
#                 "experiment": "decadal1960",
#                 "time_frequency": "mon",
#                 "realm": "atmos",
#                 "cmip_table": "Amon",
#                 "ensemble": "r10i2p1",
#                 "version": "files",
#                 "variable": "hfls_20110627"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej/items/dedf8eba79d33915098b5be54a3fab71"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "dedf8eba79d33915098b5be54a3fab71": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip5/data/cmip5/output1/MOHC/HadCM3/decadal1960/mon/atmos/Amon/r10i2p1/files/hfls_20110627/hfls_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "type": "application/octet-stream",
#                     "title": "hfls_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "c83f2f943d306f0b6677b1b919340d27",
#             "collection": "Ca1oVHsBhuk7QqVbE5ej",
#             "bbox": null,
#             "properties": {
#                 "datacentre": "BADC",
#                 "platform": "cmip5",
#                 "product": "output1",
#                 "institute": "MOHC",
#                 "model": "HadCM3",
#                 "experiment": "decadal1960",
#                 "time_frequency": "mon",
#                 "realm": "atmos",
#                 "cmip_table": "Amon",
#                 "ensemble": "r10i2p1",
#                 "version": "files",
#                 "variable": "hfss_20110627"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej/items/c83f2f943d306f0b6677b1b919340d27"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "c83f2f943d306f0b6677b1b919340d27": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip5/data/cmip5/output1/MOHC/HadCM3/decadal1960/mon/atmos/Amon/r10i2p1/files/hfss_20110627/hfss_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "type": "application/octet-stream",
#                     "title": "hfss_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "99bf88ea4d6b101bf52c4c436c6cf6e2",
#             "collection": "Ca1oVHsBhuk7QqVbE5ej",
#             "bbox": null,
#             "properties": {
#                 "datacentre": "BADC",
#                 "platform": "cmip5",
#                 "product": "output1",
#                 "institute": "MOHC",
#                 "model": "HadCM3",
#                 "experiment": "decadal1960",
#                 "time_frequency": "mon",
#                 "realm": "atmos",
#                 "cmip_table": "Amon",
#                 "ensemble": "r10i2p1",
#                 "version": "files",
#                 "variable": "hur_20110627"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej/items/99bf88ea4d6b101bf52c4c436c6cf6e2"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "99bf88ea4d6b101bf52c4c436c6cf6e2": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip5/data/cmip5/output1/MOHC/HadCM3/decadal1960/mon/atmos/Amon/r10i2p1/files/hur_20110627/hur_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "type": "application/octet-stream",
#                     "title": "hur_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "05c46c4dfce42f552e9d29202695f9f8",
#             "collection": "Ca1oVHsBhuk7QqVbE5ej",
#             "bbox": null,
#             "properties": {
#                 "datacentre": "BADC",
#                 "platform": "cmip5",
#                 "product": "output1",
#                 "institute": "MOHC",
#                 "model": "HadCM3",
#                 "experiment": "decadal1960",
#                 "time_frequency": "mon",
#                 "realm": "atmos",
#                 "cmip_table": "Amon",
#                 "ensemble": "r10i2p1",
#                 "version": "files",
#                 "variable": "hurs_20110627"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej/items/05c46c4dfce42f552e9d29202695f9f8"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "05c46c4dfce42f552e9d29202695f9f8": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip5/data/cmip5/output1/MOHC/HadCM3/decadal1960/mon/atmos/Amon/r10i2p1/files/hurs_20110627/hurs_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "type": "application/octet-stream",
#                     "title": "hurs_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "8a1ca74f261e83b971c8634ec54ad03d",
#             "collection": "Ca1oVHsBhuk7QqVbE5ej",
#             "bbox": null,
#             "properties": {
#                 "datacentre": "BADC",
#                 "platform": "cmip5",
#                 "product": "output1",
#                 "institute": "MOHC",
#                 "model": "HadCM3",
#                 "experiment": "decadal1960",
#                 "time_frequency": "mon",
#                 "realm": "atmos",
#                 "cmip_table": "Amon",
#                 "ensemble": "r10i2p1",
#                 "version": "files",
#                 "variable": "huss_20110627"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej/items/8a1ca74f261e83b971c8634ec54ad03d"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "8a1ca74f261e83b971c8634ec54ad03d": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip5/data/cmip5/output1/MOHC/HadCM3/decadal1960/mon/atmos/Amon/r10i2p1/files/huss_20110627/huss_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "type": "application/octet-stream",
#                     "title": "huss_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "75a40f93f900625a0f4a021b686718c2",
#             "collection": "Ca1oVHsBhuk7QqVbE5ej",
#             "bbox": null,
#             "properties": {
#                 "datacentre": "BADC",
#                 "platform": "cmip5",
#                 "product": "output1",
#                 "institute": "MOHC",
#                 "model": "HadCM3",
#                 "experiment": "decadal1960",
#                 "time_frequency": "mon",
#                 "realm": "atmos",
#                 "cmip_table": "Amon",
#                 "ensemble": "r10i2p1",
#                 "version": "files",
#                 "variable": "pr_20110627"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej/items/75a40f93f900625a0f4a021b686718c2"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "75a40f93f900625a0f4a021b686718c2": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip5/data/cmip5/output1/MOHC/HadCM3/decadal1960/mon/atmos/Amon/r10i2p1/files/pr_20110627/pr_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "type": "application/octet-stream",
#                     "title": "pr_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "272e0470c0b6560c9a6777fdf6db8ebd",
#             "collection": "Ca1oVHsBhuk7QqVbE5ej",
#             "bbox": null,
#             "properties": {
#                 "datacentre": "BADC",
#                 "platform": "cmip5",
#                 "product": "output1",
#                 "institute": "MOHC",
#                 "model": "HadCM3",
#                 "experiment": "decadal1960",
#                 "time_frequency": "mon",
#                 "realm": "atmos",
#                 "cmip_table": "Amon",
#                 "ensemble": "r10i2p1",
#                 "version": "files",
#                 "variable": "prc_20110627"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej/items/272e0470c0b6560c9a6777fdf6db8ebd"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "272e0470c0b6560c9a6777fdf6db8ebd": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip5/data/cmip5/output1/MOHC/HadCM3/decadal1960/mon/atmos/Amon/r10i2p1/files/prc_20110627/prc_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "type": "application/octet-stream",
#                     "title": "prc_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "2e12cb5650594867d3efb67f96a57f04",
#             "collection": "Ca1oVHsBhuk7QqVbE5ej",
#             "bbox": null,
#             "properties": {
#                 "datacentre": "BADC",
#                 "platform": "cmip5",
#                 "product": "output1",
#                 "institute": "MOHC",
#                 "model": "HadCM3",
#                 "experiment": "decadal1960",
#                 "time_frequency": "mon",
#                 "realm": "atmos",
#                 "cmip_table": "Amon",
#                 "ensemble": "r10i2p1",
#                 "version": "files",
#                 "variable": "prsn_20110627"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej/items/2e12cb5650594867d3efb67f96a57f04"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "2e12cb5650594867d3efb67f96a57f04": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip5/data/cmip5/output1/MOHC/HadCM3/decadal1960/mon/atmos/Amon/r10i2p1/files/prsn_20110627/prsn_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "type": "application/octet-stream",
#                     "title": "prsn_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         }
#     ],
#     "links": [
#         {
#             "rel": "self",
#             "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej/items?page=1"
#         },
#         {
#             "rel": "next",
#             "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej/items?page=2"
#         }
#     ],
#     "context": {
#         "returned": 10,
#         "limit": 10,
#         "matched": 2600
#     }
# }

# %% [markdown]
# ### GET Item
#
# **/collections/{collectionId}/items/{itemId}**
#
# Retrieve an item object, from a specific collection, given an item ID.

# %%
item_id = items['features'][0]['id']

item = collection.get_items(item_id=item_id)
display(item)
# Out:
# {
#     "type": "Feature",
#     "stac_version": "1.0.0",
#     "stac_extensions": [],
#     "id": "7b7f9b274fb11aa835699556b238a407",
#     "collection": "Ca1oVHsBhuk7QqVbE5ej",
#     "bbox": null,
#     "properties": {
#         "datacentre": "BADC",
#         "platform": "cmip5",
#         "product": "output1",
#         "institute": "MOHC",
#         "model": "HadCM3",
#         "experiment": "decadal1960",
#         "time_frequency": "mon",
#         "realm": "atmos",
#         "cmip_table": "Amon",
#         "ensemble": "r10i2p1",
#         "version": "files",
#         "variable": "clt_20110627"
#     },
#     "links": [
#         {
#             "rel": "self",
#             "type": "application/geo+json",
#             "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej/items/7b7f9b274fb11aa835699556b238a407"
#         },
#         {
#             "rel": "parent",
#             "type": "application/json",
#             "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#         },
#         {
#             "rel": "collection",
#             "type": "application/json",
#             "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#         },
#         {
#             "rel": "root",
#             "type": "application/json",
#             "href": "https://api.stac.ceda.ac.uk/"
#         }
#     ],
#     "assets": {
#         "7b7f9b274fb11aa835699556b238a407": {
#             "href": "https://dap.ceda.ac.uk/badc/cmip5/data/cmip5/output1/MOHC/HadCM3/decadal1960/mon/atmos/Amon/r10i2p1/files/clt_20110627/clt_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#             "type": "application/octet-stream",
#             "title": "clt_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#             "roles": [
#                 "data"
#             ]
#         }
#     }
# }
# /Users/kazi.mahir/python-virtual-environments/stac/lib/python3.9/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.stac.ceda.ac.uk'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %% [markdown]
# ### GET Assets
#
# Retrieve a list of assets of a given item.

# %%
assets = item.assets
display(assets)
# Out:
# {
#     "7b7f9b274fb11aa835699556b238a407": {
#         "href": "https://dap.ceda.ac.uk/badc/cmip5/data/cmip5/output1/MOHC/HadCM3/decadal1960/mon/atmos/Amon/r10i2p1/files/clt_20110627/clt_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#         "type": "application/octet-stream",
#         "title": "clt_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#         "roles": [
#             "data"
#         ]
#     }
# }

# %% [markdown]
# ## Search
#
# Usages examples of how search using the python wrapper client.
# (See Conformance classes `item-search` for capabilities)
#
# ### Basic Usage:
#
# Search the STAC endpoint by filtering through these optional keys:
# * collections: list of collection IDs
# * ids: list of item IDs
# * bbox: list of integers for bounding box
# * datetime: string of open/closed ended dates or single date.
# * limit: number of items to list in one page. *Default 10*.

# %%
result = Client.search()
# returns every item available
display(result)
# Out:
# /Users/kazi.mahir/python-virtual-environments/stac/lib/python3.9/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.stac.ceda.ac.uk'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# {
#     "type": "FeatureCollection",
#     "features": [
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "7b7f9b274fb11aa835699556b238a407",
#             "collection": "Ca1oVHsBhuk7QqVbE5ej",
#             "bbox": null,
#             "properties": {
#                 "datacentre": "BADC",
#                 "platform": "cmip5",
#                 "product": "output1",
#                 "institute": "MOHC",
#                 "model": "HadCM3",
#                 "experiment": "decadal1960",
#                 "time_frequency": "mon",
#                 "realm": "atmos",
#                 "cmip_table": "Amon",
#                 "ensemble": "r10i2p1",
#                 "version": "files",
#                 "variable": "clt_20110627"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej/items/7b7f9b274fb11aa835699556b238a407"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "7b7f9b274fb11aa835699556b238a407": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip5/data/cmip5/output1/MOHC/HadCM3/decadal1960/mon/atmos/Amon/r10i2p1/files/clt_20110627/clt_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "type": "application/octet-stream",
#                     "title": "clt_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "9fe215254c4be9b50c117fe799309f63",
#             "collection": "Ca1oVHsBhuk7QqVbE5ej",
#             "bbox": null,
#             "properties": {
#                 "datacentre": "BADC",
#                 "platform": "cmip5",
#                 "product": "output1",
#                 "institute": "MOHC",
#                 "model": "HadCM3",
#                 "experiment": "decadal1960",
#                 "time_frequency": "mon",
#                 "realm": "atmos",
#                 "cmip_table": "Amon",
#                 "ensemble": "r10i2p1",
#                 "version": "files",
#                 "variable": "evspsbl_20110627"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej/items/9fe215254c4be9b50c117fe799309f63"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "9fe215254c4be9b50c117fe799309f63": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip5/data/cmip5/output1/MOHC/HadCM3/decadal1960/mon/atmos/Amon/r10i2p1/files/evspsbl_20110627/evspsbl_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "type": "application/octet-stream",
#                     "title": "evspsbl_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "dedf8eba79d33915098b5be54a3fab71",
#             "collection": "Ca1oVHsBhuk7QqVbE5ej",
#             "bbox": null,
#             "properties": {
#                 "datacentre": "BADC",
#                 "platform": "cmip5",
#                 "product": "output1",
#                 "institute": "MOHC",
#                 "model": "HadCM3",
#                 "experiment": "decadal1960",
#                 "time_frequency": "mon",
#                 "realm": "atmos",
#                 "cmip_table": "Amon",
#                 "ensemble": "r10i2p1",
#                 "version": "files",
#                 "variable": "hfls_20110627"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej/items/dedf8eba79d33915098b5be54a3fab71"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "dedf8eba79d33915098b5be54a3fab71": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip5/data/cmip5/output1/MOHC/HadCM3/decadal1960/mon/atmos/Amon/r10i2p1/files/hfls_20110627/hfls_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "type": "application/octet-stream",
#                     "title": "hfls_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "c83f2f943d306f0b6677b1b919340d27",
#             "collection": "Ca1oVHsBhuk7QqVbE5ej",
#             "bbox": null,
#             "properties": {
#                 "datacentre": "BADC",
#                 "platform": "cmip5",
#                 "product": "output1",
#                 "institute": "MOHC",
#                 "model": "HadCM3",
#                 "experiment": "decadal1960",
#                 "time_frequency": "mon",
#                 "realm": "atmos",
#                 "cmip_table": "Amon",
#                 "ensemble": "r10i2p1",
#                 "version": "files",
#                 "variable": "hfss_20110627"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej/items/c83f2f943d306f0b6677b1b919340d27"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "c83f2f943d306f0b6677b1b919340d27": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip5/data/cmip5/output1/MOHC/HadCM3/decadal1960/mon/atmos/Amon/r10i2p1/files/hfss_20110627/hfss_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "type": "application/octet-stream",
#                     "title": "hfss_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "99bf88ea4d6b101bf52c4c436c6cf6e2",
#             "collection": "Ca1oVHsBhuk7QqVbE5ej",
#             "bbox": null,
#             "properties": {
#                 "datacentre": "BADC",
#                 "platform": "cmip5",
#                 "product": "output1",
#                 "institute": "MOHC",
#                 "model": "HadCM3",
#                 "experiment": "decadal1960",
#                 "time_frequency": "mon",
#                 "realm": "atmos",
#                 "cmip_table": "Amon",
#                 "ensemble": "r10i2p1",
#                 "version": "files",
#                 "variable": "hur_20110627"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej/items/99bf88ea4d6b101bf52c4c436c6cf6e2"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "99bf88ea4d6b101bf52c4c436c6cf6e2": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip5/data/cmip5/output1/MOHC/HadCM3/decadal1960/mon/atmos/Amon/r10i2p1/files/hur_20110627/hur_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "type": "application/octet-stream",
#                     "title": "hur_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "05c46c4dfce42f552e9d29202695f9f8",
#             "collection": "Ca1oVHsBhuk7QqVbE5ej",
#             "bbox": null,
#             "properties": {
#                 "datacentre": "BADC",
#                 "platform": "cmip5",
#                 "product": "output1",
#                 "institute": "MOHC",
#                 "model": "HadCM3",
#                 "experiment": "decadal1960",
#                 "time_frequency": "mon",
#                 "realm": "atmos",
#                 "cmip_table": "Amon",
#                 "ensemble": "r10i2p1",
#                 "version": "files",
#                 "variable": "hurs_20110627"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej/items/05c46c4dfce42f552e9d29202695f9f8"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "05c46c4dfce42f552e9d29202695f9f8": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip5/data/cmip5/output1/MOHC/HadCM3/decadal1960/mon/atmos/Amon/r10i2p1/files/hurs_20110627/hurs_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "type": "application/octet-stream",
#                     "title": "hurs_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "8a1ca74f261e83b971c8634ec54ad03d",
#             "collection": "Ca1oVHsBhuk7QqVbE5ej",
#             "bbox": null,
#             "properties": {
#                 "datacentre": "BADC",
#                 "platform": "cmip5",
#                 "product": "output1",
#                 "institute": "MOHC",
#                 "model": "HadCM3",
#                 "experiment": "decadal1960",
#                 "time_frequency": "mon",
#                 "realm": "atmos",
#                 "cmip_table": "Amon",
#                 "ensemble": "r10i2p1",
#                 "version": "files",
#                 "variable": "huss_20110627"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej/items/8a1ca74f261e83b971c8634ec54ad03d"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "8a1ca74f261e83b971c8634ec54ad03d": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip5/data/cmip5/output1/MOHC/HadCM3/decadal1960/mon/atmos/Amon/r10i2p1/files/huss_20110627/huss_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "type": "application/octet-stream",
#                     "title": "huss_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "75a40f93f900625a0f4a021b686718c2",
#             "collection": "Ca1oVHsBhuk7QqVbE5ej",
#             "bbox": null,
#             "properties": {
#                 "datacentre": "BADC",
#                 "platform": "cmip5",
#                 "product": "output1",
#                 "institute": "MOHC",
#                 "model": "HadCM3",
#                 "experiment": "decadal1960",
#                 "time_frequency": "mon",
#                 "realm": "atmos",
#                 "cmip_table": "Amon",
#                 "ensemble": "r10i2p1",
#                 "version": "files",
#                 "variable": "pr_20110627"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej/items/75a40f93f900625a0f4a021b686718c2"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "75a40f93f900625a0f4a021b686718c2": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip5/data/cmip5/output1/MOHC/HadCM3/decadal1960/mon/atmos/Amon/r10i2p1/files/pr_20110627/pr_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "type": "application/octet-stream",
#                     "title": "pr_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "272e0470c0b6560c9a6777fdf6db8ebd",
#             "collection": "Ca1oVHsBhuk7QqVbE5ej",
#             "bbox": null,
#             "properties": {
#                 "datacentre": "BADC",
#                 "platform": "cmip5",
#                 "product": "output1",
#                 "institute": "MOHC",
#                 "model": "HadCM3",
#                 "experiment": "decadal1960",
#                 "time_frequency": "mon",
#                 "realm": "atmos",
#                 "cmip_table": "Amon",
#                 "ensemble": "r10i2p1",
#                 "version": "files",
#                 "variable": "prc_20110627"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej/items/272e0470c0b6560c9a6777fdf6db8ebd"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "272e0470c0b6560c9a6777fdf6db8ebd": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip5/data/cmip5/output1/MOHC/HadCM3/decadal1960/mon/atmos/Amon/r10i2p1/files/prc_20110627/prc_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "type": "application/octet-stream",
#                     "title": "prc_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "2e12cb5650594867d3efb67f96a57f04",
#             "collection": "Ca1oVHsBhuk7QqVbE5ej",
#             "bbox": null,
#             "properties": {
#                 "datacentre": "BADC",
#                 "platform": "cmip5",
#                 "product": "output1",
#                 "institute": "MOHC",
#                 "model": "HadCM3",
#                 "experiment": "decadal1960",
#                 "time_frequency": "mon",
#                 "realm": "atmos",
#                 "cmip_table": "Amon",
#                 "ensemble": "r10i2p1",
#                 "version": "files",
#                 "variable": "prsn_20110627"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej/items/2e12cb5650594867d3efb67f96a57f04"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "2e12cb5650594867d3efb67f96a57f04": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip5/data/cmip5/output1/MOHC/HadCM3/decadal1960/mon/atmos/Amon/r10i2p1/files/prsn_20110627/prsn_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "type": "application/octet-stream",
#                     "title": "prsn_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         }
#     ],
#     "links": [
#         {
#             "rel": "self",
#             "href": "https://api.stac.ceda.ac.uk/search?page=1"
#         },
#         {
#             "rel": "next",
#             "href": "https://api.stac.ceda.ac.uk/search?page=2"
#         }
#     ],
#     "context": {
#         "returned": 10,
#         "limit": 10,
#         "matched": 4080,
#         "collections": [
#             "Ca1oVHsBhuk7QqVbE5ej",
#             "WH5qEHoBZp5aDdjsfMv-",
#             "Ic93XnsBhuk7QqVbSFwS",
#             "Fj3reHsBhuk7QqVbt7P-",
#             "wiLHc3sBhuk7QqVbjTmQ"
#         ]
#     }
# }

# %%
result = Client.search(
    collections=[collection_id],
    limit=10
)
display(result)
# Out:
# {
#     "type": "FeatureCollection",
#     "features": [
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "7b7f9b274fb11aa835699556b238a407",
#             "collection": "Ca1oVHsBhuk7QqVbE5ej",
#             "bbox": null,
#             "properties": {
#                 "datacentre": "BADC",
#                 "platform": "cmip5",
#                 "product": "output1",
#                 "institute": "MOHC",
#                 "model": "HadCM3",
#                 "experiment": "decadal1960",
#                 "time_frequency": "mon",
#                 "realm": "atmos",
#                 "cmip_table": "Amon",
#                 "ensemble": "r10i2p1",
#                 "version": "files",
#                 "variable": "clt_20110627"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej/items/7b7f9b274fb11aa835699556b238a407"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "7b7f9b274fb11aa835699556b238a407": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip5/data/cmip5/output1/MOHC/HadCM3/decadal1960/mon/atmos/Amon/r10i2p1/files/clt_20110627/clt_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "type": "application/octet-stream",
#                     "title": "clt_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "9fe215254c4be9b50c117fe799309f63",
#             "collection": "Ca1oVHsBhuk7QqVbE5ej",
#             "bbox": null,
#             "properties": {
#                 "datacentre": "BADC",
#                 "platform": "cmip5",
#                 "product": "output1",
#                 "institute": "MOHC",
#                 "model": "HadCM3",
#                 "experiment": "decadal1960",
#                 "time_frequency": "mon",
#                 "realm": "atmos",
#                 "cmip_table": "Amon",
#                 "ensemble": "r10i2p1",
#                 "version": "files",
#                 "variable": "evspsbl_20110627"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej/items/9fe215254c4be9b50c117fe799309f63"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "9fe215254c4be9b50c117fe799309f63": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip5/data/cmip5/output1/MOHC/HadCM3/decadal1960/mon/atmos/Amon/r10i2p1/files/evspsbl_20110627/evspsbl_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "type": "application/octet-stream",
#                     "title": "evspsbl_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "dedf8eba79d33915098b5be54a3fab71",
#             "collection": "Ca1oVHsBhuk7QqVbE5ej",
#             "bbox": null,
#             "properties": {
#                 "datacentre": "BADC",
#                 "platform": "cmip5",
#                 "product": "output1",
#                 "institute": "MOHC",
#                 "model": "HadCM3",
#                 "experiment": "decadal1960",
#                 "time_frequency": "mon",
#                 "realm": "atmos",
#                 "cmip_table": "Amon",
#                 "ensemble": "r10i2p1",
#                 "version": "files",
#                 "variable": "hfls_20110627"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej/items/dedf8eba79d33915098b5be54a3fab71"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "dedf8eba79d33915098b5be54a3fab71": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip5/data/cmip5/output1/MOHC/HadCM3/decadal1960/mon/atmos/Amon/r10i2p1/files/hfls_20110627/hfls_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "type": "application/octet-stream",
#                     "title": "hfls_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "c83f2f943d306f0b6677b1b919340d27",
#             "collection": "Ca1oVHsBhuk7QqVbE5ej",
#             "bbox": null,
#             "properties": {
#                 "datacentre": "BADC",
#                 "platform": "cmip5",
#                 "product": "output1",
#                 "institute": "MOHC",
#                 "model": "HadCM3",
#                 "experiment": "decadal1960",
#                 "time_frequency": "mon",
#                 "realm": "atmos",
#                 "cmip_table": "Amon",
#                 "ensemble": "r10i2p1",
#                 "version": "files",
#                 "variable": "hfss_20110627"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej/items/c83f2f943d306f0b6677b1b919340d27"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "c83f2f943d306f0b6677b1b919340d27": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip5/data/cmip5/output1/MOHC/HadCM3/decadal1960/mon/atmos/Amon/r10i2p1/files/hfss_20110627/hfss_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "type": "application/octet-stream",
#                     "title": "hfss_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "99bf88ea4d6b101bf52c4c436c6cf6e2",
#             "collection": "Ca1oVHsBhuk7QqVbE5ej",
#             "bbox": null,
#             "properties": {
#                 "datacentre": "BADC",
#                 "platform": "cmip5",
#                 "product": "output1",
#                 "institute": "MOHC",
#                 "model": "HadCM3",
#                 "experiment": "decadal1960",
#                 "time_frequency": "mon",
#                 "realm": "atmos",
#                 "cmip_table": "Amon",
#                 "ensemble": "r10i2p1",
#                 "version": "files",
#                 "variable": "hur_20110627"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej/items/99bf88ea4d6b101bf52c4c436c6cf6e2"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "99bf88ea4d6b101bf52c4c436c6cf6e2": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip5/data/cmip5/output1/MOHC/HadCM3/decadal1960/mon/atmos/Amon/r10i2p1/files/hur_20110627/hur_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "type": "application/octet-stream",
#                     "title": "hur_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "05c46c4dfce42f552e9d29202695f9f8",
#             "collection": "Ca1oVHsBhuk7QqVbE5ej",
#             "bbox": null,
#             "properties": {
#                 "datacentre": "BADC",
#                 "platform": "cmip5",
#                 "product": "output1",
#                 "institute": "MOHC",
#                 "model": "HadCM3",
#                 "experiment": "decadal1960",
#                 "time_frequency": "mon",
#                 "realm": "atmos",
#                 "cmip_table": "Amon",
#                 "ensemble": "r10i2p1",
#                 "version": "files",
#                 "variable": "hurs_20110627"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej/items/05c46c4dfce42f552e9d29202695f9f8"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "05c46c4dfce42f552e9d29202695f9f8": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip5/data/cmip5/output1/MOHC/HadCM3/decadal1960/mon/atmos/Amon/r10i2p1/files/hurs_20110627/hurs_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "type": "application/octet-stream",
#                     "title": "hurs_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "8a1ca74f261e83b971c8634ec54ad03d",
#             "collection": "Ca1oVHsBhuk7QqVbE5ej",
#             "bbox": null,
#             "properties": {
#                 "datacentre": "BADC",
#                 "platform": "cmip5",
#                 "product": "output1",
#                 "institute": "MOHC",
#                 "model": "HadCM3",
#                 "experiment": "decadal1960",
#                 "time_frequency": "mon",
#                 "realm": "atmos",
#                 "cmip_table": "Amon",
#                 "ensemble": "r10i2p1",
#                 "version": "files",
#                 "variable": "huss_20110627"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej/items/8a1ca74f261e83b971c8634ec54ad03d"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "8a1ca74f261e83b971c8634ec54ad03d": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip5/data/cmip5/output1/MOHC/HadCM3/decadal1960/mon/atmos/Amon/r10i2p1/files/huss_20110627/huss_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "type": "application/octet-stream",
#                     "title": "huss_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "75a40f93f900625a0f4a021b686718c2",
#             "collection": "Ca1oVHsBhuk7QqVbE5ej",
#             "bbox": null,
#             "properties": {
#                 "datacentre": "BADC",
#                 "platform": "cmip5",
#                 "product": "output1",
#                 "institute": "MOHC",
#                 "model": "HadCM3",
#                 "experiment": "decadal1960",
#                 "time_frequency": "mon",
#                 "realm": "atmos",
#                 "cmip_table": "Amon",
#                 "ensemble": "r10i2p1",
#                 "version": "files",
#                 "variable": "pr_20110627"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej/items/75a40f93f900625a0f4a021b686718c2"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "75a40f93f900625a0f4a021b686718c2": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip5/data/cmip5/output1/MOHC/HadCM3/decadal1960/mon/atmos/Amon/r10i2p1/files/pr_20110627/pr_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "type": "application/octet-stream",
#                     "title": "pr_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "272e0470c0b6560c9a6777fdf6db8ebd",
#             "collection": "Ca1oVHsBhuk7QqVbE5ej",
#             "bbox": null,
#             "properties": {
#                 "datacentre": "BADC",
#                 "platform": "cmip5",
#                 "product": "output1",
#                 "institute": "MOHC",
#                 "model": "HadCM3",
#                 "experiment": "decadal1960",
#                 "time_frequency": "mon",
#                 "realm": "atmos",
#                 "cmip_table": "Amon",
#                 "ensemble": "r10i2p1",
#                 "version": "files",
#                 "variable": "prc_20110627"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej/items/272e0470c0b6560c9a6777fdf6db8ebd"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "272e0470c0b6560c9a6777fdf6db8ebd": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip5/data/cmip5/output1/MOHC/HadCM3/decadal1960/mon/atmos/Amon/r10i2p1/files/prc_20110627/prc_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "type": "application/octet-stream",
#                     "title": "prc_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "2e12cb5650594867d3efb67f96a57f04",
#             "collection": "Ca1oVHsBhuk7QqVbE5ej",
#             "bbox": null,
#             "properties": {
#                 "datacentre": "BADC",
#                 "platform": "cmip5",
#                 "product": "output1",
#                 "institute": "MOHC",
#                 "model": "HadCM3",
#                 "experiment": "decadal1960",
#                 "time_frequency": "mon",
#                 "realm": "atmos",
#                 "cmip_table": "Amon",
#                 "ensemble": "r10i2p1",
#                 "version": "files",
#                 "variable": "prsn_20110627"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej/items/2e12cb5650594867d3efb67f96a57f04"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Ca1oVHsBhuk7QqVbE5ej"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "2e12cb5650594867d3efb67f96a57f04": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip5/data/cmip5/output1/MOHC/HadCM3/decadal1960/mon/atmos/Amon/r10i2p1/files/prsn_20110627/prsn_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "type": "application/octet-stream",
#                     "title": "prsn_Amon_HadCM3_decadal1960_r10i2p1_196011-199012.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         }
#     ],
#     "links": [
#         {
#             "rel": "self",
#             "href": "https://api.stac.ceda.ac.uk/search?collections=Ca1oVHsBhuk7QqVbE5ej&limit=10&page=1"
#         },
#         {
#             "rel": "next",
#             "href": "https://api.stac.ceda.ac.uk/search?collections=Ca1oVHsBhuk7QqVbE5ej&limit=10&page=2"
#         }
#     ],
#     "context": {
#         "returned": 10,
#         "limit": 10,
#         "matched": 2600,
#         "collections": [
#             "Ca1oVHsBhuk7QqVbE5ej"
#         ]
#     }
# }
# /Users/kazi.mahir/python-virtual-environments/stac/lib/python3.9/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.stac.ceda.ac.uk'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %% [markdown]
# ### Free Text Search
#
# Free text search is provided by the client, using a positional argument as the first
# or by the `q` parameter.
# Free text search supports case-insensitive and partial search.
#
# Free text search is provided by this STAC extension:
#
# - https://api.stacspec.org/v1.0.0-beta.2/item-search#free-text-search

# %%
# All these queries end up with the same search result:

result = Client.search(q="AerChemMIP")
display(result)
# Out:
# {
#     "type": "FeatureCollection",
#     "features": [
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "5ad82e4c683d7dd9865c3849677b135e",
#             "collection": "Fj3reHsBhuk7QqVbt7P-",
#             "bbox": null,
#             "properties": {
#                 "var_id": "ch4",
#                 "table_id": "Amon",
#                 "source_id": "CNRM-ESM2-1",
#                 "experiment_id": "hist-1950HC",
#                 "realization_index": "2",
#                 "initialisation_index": "1",
#                 "physics_index": "1",
#                 "forcing_index": "2",
#                 "grid_label": "gr",
#                 "start_datetime": "1950-01-01T00:00:00",
#                 "end_datetime": "2014-12-01T00:00:00",
#                 "mip_era": "CMIP6",
#                 "activity_id": "AerChemMIP",
#                 "institution_id": "CNRM-CERFACS",
#                 "version": "20190621"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-/items/5ad82e4c683d7dd9865c3849677b135e"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "965a73f1c0f0a51e308183e258d38577": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip6/data/CMIP6/AerChemMIP/CNRM-CERFACS/CNRM-ESM2-1/hist-1950HC/r2i1p1f2/Amon/ch4/gr/v20190621/ch4_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "type": "inode/symlink",
#                     "title": "ch4_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "1ccc129d883d6855bc7a2591b652171e",
#             "collection": "Fj3reHsBhuk7QqVbt7P-",
#             "bbox": null,
#             "properties": {
#                 "var_id": "clivi",
#                 "table_id": "Amon",
#                 "source_id": "CNRM-ESM2-1",
#                 "experiment_id": "hist-1950HC",
#                 "realization_index": "2",
#                 "initialisation_index": "1",
#                 "physics_index": "1",
#                 "forcing_index": "2",
#                 "grid_label": "gr",
#                 "start_datetime": "1950-01-01T00:00:00",
#                 "end_datetime": "2014-12-01T00:00:00",
#                 "mip_era": "CMIP6",
#                 "activity_id": "AerChemMIP",
#                 "institution_id": "CNRM-CERFACS",
#                 "version": "20190621"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-/items/1ccc129d883d6855bc7a2591b652171e"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "ba61ec5fa0731b3ae2df6533bfa056d1": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip6/data/CMIP6/AerChemMIP/CNRM-CERFACS/CNRM-ESM2-1/hist-1950HC/r2i1p1f2/Amon/clivi/gr/v20190621/clivi_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "type": "inode/symlink",
#                     "title": "clivi_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "0d3af2dc6477148ed733ffecc5cf4208",
#             "collection": "Fj3reHsBhuk7QqVbt7P-",
#             "bbox": null,
#             "properties": {
#                 "var_id": "clt",
#                 "table_id": "Amon",
#                 "source_id": "CNRM-ESM2-1",
#                 "experiment_id": "hist-1950HC",
#                 "realization_index": "2",
#                 "initialisation_index": "1",
#                 "physics_index": "1",
#                 "forcing_index": "2",
#                 "grid_label": "gr",
#                 "start_datetime": "1950-01-01T00:00:00",
#                 "end_datetime": "2014-12-01T00:00:00",
#                 "mip_era": "CMIP6",
#                 "activity_id": "AerChemMIP",
#                 "institution_id": "CNRM-CERFACS",
#                 "version": "20190621"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-/items/0d3af2dc6477148ed733ffecc5cf4208"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "8a36e9df8ed59bb74c36857bc149a404": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip6/data/CMIP6/AerChemMIP/CNRM-CERFACS/CNRM-ESM2-1/hist-1950HC/r2i1p1f2/Amon/clt/gr/v20190621/clt_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "type": "inode/symlink",
#                     "title": "clt_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "cecffa1faeaf0e1132a44504ae0b75fe",
#             "collection": "Fj3reHsBhuk7QqVbt7P-",
#             "bbox": null,
#             "properties": {
#                 "var_id": "clwvi",
#                 "table_id": "Amon",
#                 "source_id": "CNRM-ESM2-1",
#                 "experiment_id": "hist-1950HC",
#                 "realization_index": "2",
#                 "initialisation_index": "1",
#                 "physics_index": "1",
#                 "forcing_index": "2",
#                 "grid_label": "gr",
#                 "start_datetime": "1950-01-01T00:00:00",
#                 "end_datetime": "2014-12-01T00:00:00",
#                 "mip_era": "CMIP6",
#                 "activity_id": "AerChemMIP",
#                 "institution_id": "CNRM-CERFACS",
#                 "version": "20190621"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-/items/cecffa1faeaf0e1132a44504ae0b75fe"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "d05760c2ce9dacb2851d5db51e3dc755": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip6/data/CMIP6/AerChemMIP/CNRM-CERFACS/CNRM-ESM2-1/hist-1950HC/r2i1p1f2/Amon/clwvi/gr/v20190621/clwvi_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "type": "inode/symlink",
#                     "title": "clwvi_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "f5925c2077c8803e9685d20ba1444dbb",
#             "collection": "Fj3reHsBhuk7QqVbt7P-",
#             "bbox": null,
#             "properties": {
#                 "var_id": "co2",
#                 "table_id": "Amon",
#                 "source_id": "CNRM-ESM2-1",
#                 "experiment_id": "hist-1950HC",
#                 "realization_index": "2",
#                 "initialisation_index": "1",
#                 "physics_index": "1",
#                 "forcing_index": "2",
#                 "grid_label": "gr",
#                 "start_datetime": "1950-01-01T00:00:00",
#                 "end_datetime": "2014-12-01T00:00:00",
#                 "mip_era": "CMIP6",
#                 "activity_id": "AerChemMIP",
#                 "institution_id": "CNRM-CERFACS",
#                 "version": "20190621"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-/items/f5925c2077c8803e9685d20ba1444dbb"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "45b00a6238653db458aa83bb48c537f7": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip6/data/CMIP6/AerChemMIP/CNRM-CERFACS/CNRM-ESM2-1/hist-1950HC/r2i1p1f2/Amon/co2/gr/v20190621/co2_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "type": "inode/symlink",
#                     "title": "co2_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "6de4996cae53fb86d4e65e0c91f71cde",
#             "collection": "Fj3reHsBhuk7QqVbt7P-",
#             "bbox": null,
#             "properties": {
#                 "var_id": "evspsbl",
#                 "table_id": "Amon",
#                 "source_id": "CNRM-ESM2-1",
#                 "experiment_id": "hist-1950HC",
#                 "realization_index": "2",
#                 "initialisation_index": "1",
#                 "physics_index": "1",
#                 "forcing_index": "2",
#                 "grid_label": "gr",
#                 "start_datetime": "1950-01-01T00:00:00",
#                 "end_datetime": "2014-12-01T00:00:00",
#                 "mip_era": "CMIP6",
#                 "activity_id": "AerChemMIP",
#                 "institution_id": "CNRM-CERFACS",
#                 "version": "20190621"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-/items/6de4996cae53fb86d4e65e0c91f71cde"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "afbaa615a4fae5b51547dd9662033a30": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip6/data/CMIP6/AerChemMIP/CNRM-CERFACS/CNRM-ESM2-1/hist-1950HC/r2i1p1f2/Amon/evspsbl/gr/v20190621/evspsbl_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "type": "inode/symlink",
#                     "title": "evspsbl_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "83dab11f5ad107e5b492bef30efb74d6",
#             "collection": "Fj3reHsBhuk7QqVbt7P-",
#             "bbox": null,
#             "properties": {
#                 "var_id": "hfls",
#                 "table_id": "Amon",
#                 "source_id": "CNRM-ESM2-1",
#                 "experiment_id": "hist-1950HC",
#                 "realization_index": "2",
#                 "initialisation_index": "1",
#                 "physics_index": "1",
#                 "forcing_index": "2",
#                 "grid_label": "gr",
#                 "start_datetime": "1950-01-01T00:00:00",
#                 "end_datetime": "2014-12-01T00:00:00",
#                 "mip_era": "CMIP6",
#                 "activity_id": "AerChemMIP",
#                 "institution_id": "CNRM-CERFACS",
#                 "version": "20190621"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-/items/83dab11f5ad107e5b492bef30efb74d6"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "5b56b01f857bdeb7a1cb60173b981e9c": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip6/data/CMIP6/AerChemMIP/CNRM-CERFACS/CNRM-ESM2-1/hist-1950HC/r2i1p1f2/Amon/hfls/gr/v20190621/hfls_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "type": "inode/symlink",
#                     "title": "hfls_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "7d8a3d47529ec005b3980849aa713310",
#             "collection": "Fj3reHsBhuk7QqVbt7P-",
#             "bbox": null,
#             "properties": {
#                 "var_id": "hfss",
#                 "table_id": "Amon",
#                 "source_id": "CNRM-ESM2-1",
#                 "experiment_id": "hist-1950HC",
#                 "realization_index": "2",
#                 "initialisation_index": "1",
#                 "physics_index": "1",
#                 "forcing_index": "2",
#                 "grid_label": "gr",
#                 "start_datetime": "1950-01-01T00:00:00",
#                 "end_datetime": "2014-12-01T00:00:00",
#                 "mip_era": "CMIP6",
#                 "activity_id": "AerChemMIP",
#                 "institution_id": "CNRM-CERFACS",
#                 "version": "20190621"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-/items/7d8a3d47529ec005b3980849aa713310"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "21d4decca94ba8bb4d79426af52214ce": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip6/data/CMIP6/AerChemMIP/CNRM-CERFACS/CNRM-ESM2-1/hist-1950HC/r2i1p1f2/Amon/hfss/gr/v20190621/hfss_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "type": "inode/symlink",
#                     "title": "hfss_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "5f0fc6847068dfad162018279de5db60",
#             "collection": "Fj3reHsBhuk7QqVbt7P-",
#             "bbox": null,
#             "properties": {
#                 "var_id": "hur",
#                 "table_id": "Amon",
#                 "source_id": "CNRM-ESM2-1",
#                 "experiment_id": "hist-1950HC",
#                 "realization_index": "2",
#                 "initialisation_index": "1",
#                 "physics_index": "1",
#                 "forcing_index": "2",
#                 "grid_label": "gr",
#                 "start_datetime": "1950-01-01T00:00:00",
#                 "end_datetime": "2014-12-01T00:00:00",
#                 "mip_era": "CMIP6",
#                 "activity_id": "AerChemMIP",
#                 "institution_id": "CNRM-CERFACS",
#                 "version": "20190621"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-/items/5f0fc6847068dfad162018279de5db60"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "a3c9aaab33617d52bef17d7a95122f71": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip6/data/CMIP6/AerChemMIP/CNRM-CERFACS/CNRM-ESM2-1/hist-1950HC/r2i1p1f2/Amon/hur/gr/v20190621/hur_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "type": "inode/symlink",
#                     "title": "hur_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "b6e9f223b18cc44acf0ef0d9e75148e1",
#             "collection": "Fj3reHsBhuk7QqVbt7P-",
#             "bbox": null,
#             "properties": {
#                 "var_id": "hus",
#                 "table_id": "Amon",
#                 "source_id": "CNRM-ESM2-1",
#                 "experiment_id": "hist-1950HC",
#                 "realization_index": "2",
#                 "initialisation_index": "1",
#                 "physics_index": "1",
#                 "forcing_index": "2",
#                 "grid_label": "gr",
#                 "start_datetime": "1950-01-01T00:00:00",
#                 "end_datetime": "2014-12-01T00:00:00",
#                 "mip_era": "CMIP6",
#                 "activity_id": "AerChemMIP",
#                 "institution_id": "CNRM-CERFACS",
#                 "version": "20190621"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-/items/b6e9f223b18cc44acf0ef0d9e75148e1"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "25f402f26066de66e79bda2786f534c9": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip6/data/CMIP6/AerChemMIP/CNRM-CERFACS/CNRM-ESM2-1/hist-1950HC/r2i1p1f2/Amon/hus/gr/v20190621/hus_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "type": "inode/symlink",
#                     "title": "hus_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         }
#     ],
#     "links": [
#         {
#             "rel": "self",
#             "href": "https://api.stac.ceda.ac.uk/search?q=AerChemMIP&page=1"
#         },
#         {
#             "rel": "next",
#             "href": "https://api.stac.ceda.ac.uk/search?q=AerChemMIP&page=2"
#         }
#     ],
#     "context": {
#         "returned": 10,
#         "limit": 10,
#         "matched": 59,
#         "collections": [
#             "Fj3reHsBhuk7QqVbt7P-"
#         ]
#     }
# }
# /Users/kazi.mahir/python-virtual-environments/stac/lib/python3.9/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.stac.ceda.ac.uk'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
result = Client.search(q="aerchemmip")
display(result)
# Out:
# {
#     "type": "FeatureCollection",
#     "features": [
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "5ad82e4c683d7dd9865c3849677b135e",
#             "collection": "Fj3reHsBhuk7QqVbt7P-",
#             "bbox": null,
#             "properties": {
#                 "var_id": "ch4",
#                 "table_id": "Amon",
#                 "source_id": "CNRM-ESM2-1",
#                 "experiment_id": "hist-1950HC",
#                 "realization_index": "2",
#                 "initialisation_index": "1",
#                 "physics_index": "1",
#                 "forcing_index": "2",
#                 "grid_label": "gr",
#                 "start_datetime": "1950-01-01T00:00:00",
#                 "end_datetime": "2014-12-01T00:00:00",
#                 "mip_era": "CMIP6",
#                 "activity_id": "AerChemMIP",
#                 "institution_id": "CNRM-CERFACS",
#                 "version": "20190621"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-/items/5ad82e4c683d7dd9865c3849677b135e"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "965a73f1c0f0a51e308183e258d38577": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip6/data/CMIP6/AerChemMIP/CNRM-CERFACS/CNRM-ESM2-1/hist-1950HC/r2i1p1f2/Amon/ch4/gr/v20190621/ch4_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "type": "inode/symlink",
#                     "title": "ch4_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "1ccc129d883d6855bc7a2591b652171e",
#             "collection": "Fj3reHsBhuk7QqVbt7P-",
#             "bbox": null,
#             "properties": {
#                 "var_id": "clivi",
#                 "table_id": "Amon",
#                 "source_id": "CNRM-ESM2-1",
#                 "experiment_id": "hist-1950HC",
#                 "realization_index": "2",
#                 "initialisation_index": "1",
#                 "physics_index": "1",
#                 "forcing_index": "2",
#                 "grid_label": "gr",
#                 "start_datetime": "1950-01-01T00:00:00",
#                 "end_datetime": "2014-12-01T00:00:00",
#                 "mip_era": "CMIP6",
#                 "activity_id": "AerChemMIP",
#                 "institution_id": "CNRM-CERFACS",
#                 "version": "20190621"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-/items/1ccc129d883d6855bc7a2591b652171e"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "ba61ec5fa0731b3ae2df6533bfa056d1": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip6/data/CMIP6/AerChemMIP/CNRM-CERFACS/CNRM-ESM2-1/hist-1950HC/r2i1p1f2/Amon/clivi/gr/v20190621/clivi_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "type": "inode/symlink",
#                     "title": "clivi_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "0d3af2dc6477148ed733ffecc5cf4208",
#             "collection": "Fj3reHsBhuk7QqVbt7P-",
#             "bbox": null,
#             "properties": {
#                 "var_id": "clt",
#                 "table_id": "Amon",
#                 "source_id": "CNRM-ESM2-1",
#                 "experiment_id": "hist-1950HC",
#                 "realization_index": "2",
#                 "initialisation_index": "1",
#                 "physics_index": "1",
#                 "forcing_index": "2",
#                 "grid_label": "gr",
#                 "start_datetime": "1950-01-01T00:00:00",
#                 "end_datetime": "2014-12-01T00:00:00",
#                 "mip_era": "CMIP6",
#                 "activity_id": "AerChemMIP",
#                 "institution_id": "CNRM-CERFACS",
#                 "version": "20190621"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-/items/0d3af2dc6477148ed733ffecc5cf4208"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "8a36e9df8ed59bb74c36857bc149a404": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip6/data/CMIP6/AerChemMIP/CNRM-CERFACS/CNRM-ESM2-1/hist-1950HC/r2i1p1f2/Amon/clt/gr/v20190621/clt_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "type": "inode/symlink",
#                     "title": "clt_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "cecffa1faeaf0e1132a44504ae0b75fe",
#             "collection": "Fj3reHsBhuk7QqVbt7P-",
#             "bbox": null,
#             "properties": {
#                 "var_id": "clwvi",
#                 "table_id": "Amon",
#                 "source_id": "CNRM-ESM2-1",
#                 "experiment_id": "hist-1950HC",
#                 "realization_index": "2",
#                 "initialisation_index": "1",
#                 "physics_index": "1",
#                 "forcing_index": "2",
#                 "grid_label": "gr",
#                 "start_datetime": "1950-01-01T00:00:00",
#                 "end_datetime": "2014-12-01T00:00:00",
#                 "mip_era": "CMIP6",
#                 "activity_id": "AerChemMIP",
#                 "institution_id": "CNRM-CERFACS",
#                 "version": "20190621"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-/items/cecffa1faeaf0e1132a44504ae0b75fe"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "d05760c2ce9dacb2851d5db51e3dc755": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip6/data/CMIP6/AerChemMIP/CNRM-CERFACS/CNRM-ESM2-1/hist-1950HC/r2i1p1f2/Amon/clwvi/gr/v20190621/clwvi_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "type": "inode/symlink",
#                     "title": "clwvi_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "f5925c2077c8803e9685d20ba1444dbb",
#             "collection": "Fj3reHsBhuk7QqVbt7P-",
#             "bbox": null,
#             "properties": {
#                 "var_id": "co2",
#                 "table_id": "Amon",
#                 "source_id": "CNRM-ESM2-1",
#                 "experiment_id": "hist-1950HC",
#                 "realization_index": "2",
#                 "initialisation_index": "1",
#                 "physics_index": "1",
#                 "forcing_index": "2",
#                 "grid_label": "gr",
#                 "start_datetime": "1950-01-01T00:00:00",
#                 "end_datetime": "2014-12-01T00:00:00",
#                 "mip_era": "CMIP6",
#                 "activity_id": "AerChemMIP",
#                 "institution_id": "CNRM-CERFACS",
#                 "version": "20190621"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-/items/f5925c2077c8803e9685d20ba1444dbb"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "45b00a6238653db458aa83bb48c537f7": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip6/data/CMIP6/AerChemMIP/CNRM-CERFACS/CNRM-ESM2-1/hist-1950HC/r2i1p1f2/Amon/co2/gr/v20190621/co2_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "type": "inode/symlink",
#                     "title": "co2_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "6de4996cae53fb86d4e65e0c91f71cde",
#             "collection": "Fj3reHsBhuk7QqVbt7P-",
#             "bbox": null,
#             "properties": {
#                 "var_id": "evspsbl",
#                 "table_id": "Amon",
#                 "source_id": "CNRM-ESM2-1",
#                 "experiment_id": "hist-1950HC",
#                 "realization_index": "2",
#                 "initialisation_index": "1",
#                 "physics_index": "1",
#                 "forcing_index": "2",
#                 "grid_label": "gr",
#                 "start_datetime": "1950-01-01T00:00:00",
#                 "end_datetime": "2014-12-01T00:00:00",
#                 "mip_era": "CMIP6",
#                 "activity_id": "AerChemMIP",
#                 "institution_id": "CNRM-CERFACS",
#                 "version": "20190621"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-/items/6de4996cae53fb86d4e65e0c91f71cde"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "afbaa615a4fae5b51547dd9662033a30": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip6/data/CMIP6/AerChemMIP/CNRM-CERFACS/CNRM-ESM2-1/hist-1950HC/r2i1p1f2/Amon/evspsbl/gr/v20190621/evspsbl_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "type": "inode/symlink",
#                     "title": "evspsbl_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "83dab11f5ad107e5b492bef30efb74d6",
#             "collection": "Fj3reHsBhuk7QqVbt7P-",
#             "bbox": null,
#             "properties": {
#                 "var_id": "hfls",
#                 "table_id": "Amon",
#                 "source_id": "CNRM-ESM2-1",
#                 "experiment_id": "hist-1950HC",
#                 "realization_index": "2",
#                 "initialisation_index": "1",
#                 "physics_index": "1",
#                 "forcing_index": "2",
#                 "grid_label": "gr",
#                 "start_datetime": "1950-01-01T00:00:00",
#                 "end_datetime": "2014-12-01T00:00:00",
#                 "mip_era": "CMIP6",
#                 "activity_id": "AerChemMIP",
#                 "institution_id": "CNRM-CERFACS",
#                 "version": "20190621"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-/items/83dab11f5ad107e5b492bef30efb74d6"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "5b56b01f857bdeb7a1cb60173b981e9c": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip6/data/CMIP6/AerChemMIP/CNRM-CERFACS/CNRM-ESM2-1/hist-1950HC/r2i1p1f2/Amon/hfls/gr/v20190621/hfls_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "type": "inode/symlink",
#                     "title": "hfls_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "7d8a3d47529ec005b3980849aa713310",
#             "collection": "Fj3reHsBhuk7QqVbt7P-",
#             "bbox": null,
#             "properties": {
#                 "var_id": "hfss",
#                 "table_id": "Amon",
#                 "source_id": "CNRM-ESM2-1",
#                 "experiment_id": "hist-1950HC",
#                 "realization_index": "2",
#                 "initialisation_index": "1",
#                 "physics_index": "1",
#                 "forcing_index": "2",
#                 "grid_label": "gr",
#                 "start_datetime": "1950-01-01T00:00:00",
#                 "end_datetime": "2014-12-01T00:00:00",
#                 "mip_era": "CMIP6",
#                 "activity_id": "AerChemMIP",
#                 "institution_id": "CNRM-CERFACS",
#                 "version": "20190621"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-/items/7d8a3d47529ec005b3980849aa713310"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "21d4decca94ba8bb4d79426af52214ce": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip6/data/CMIP6/AerChemMIP/CNRM-CERFACS/CNRM-ESM2-1/hist-1950HC/r2i1p1f2/Amon/hfss/gr/v20190621/hfss_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "type": "inode/symlink",
#                     "title": "hfss_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "5f0fc6847068dfad162018279de5db60",
#             "collection": "Fj3reHsBhuk7QqVbt7P-",
#             "bbox": null,
#             "properties": {
#                 "var_id": "hur",
#                 "table_id": "Amon",
#                 "source_id": "CNRM-ESM2-1",
#                 "experiment_id": "hist-1950HC",
#                 "realization_index": "2",
#                 "initialisation_index": "1",
#                 "physics_index": "1",
#                 "forcing_index": "2",
#                 "grid_label": "gr",
#                 "start_datetime": "1950-01-01T00:00:00",
#                 "end_datetime": "2014-12-01T00:00:00",
#                 "mip_era": "CMIP6",
#                 "activity_id": "AerChemMIP",
#                 "institution_id": "CNRM-CERFACS",
#                 "version": "20190621"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-/items/5f0fc6847068dfad162018279de5db60"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "a3c9aaab33617d52bef17d7a95122f71": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip6/data/CMIP6/AerChemMIP/CNRM-CERFACS/CNRM-ESM2-1/hist-1950HC/r2i1p1f2/Amon/hur/gr/v20190621/hur_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "type": "inode/symlink",
#                     "title": "hur_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "b6e9f223b18cc44acf0ef0d9e75148e1",
#             "collection": "Fj3reHsBhuk7QqVbt7P-",
#             "bbox": null,
#             "properties": {
#                 "var_id": "hus",
#                 "table_id": "Amon",
#                 "source_id": "CNRM-ESM2-1",
#                 "experiment_id": "hist-1950HC",
#                 "realization_index": "2",
#                 "initialisation_index": "1",
#                 "physics_index": "1",
#                 "forcing_index": "2",
#                 "grid_label": "gr",
#                 "start_datetime": "1950-01-01T00:00:00",
#                 "end_datetime": "2014-12-01T00:00:00",
#                 "mip_era": "CMIP6",
#                 "activity_id": "AerChemMIP",
#                 "institution_id": "CNRM-CERFACS",
#                 "version": "20190621"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-/items/b6e9f223b18cc44acf0ef0d9e75148e1"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "25f402f26066de66e79bda2786f534c9": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip6/data/CMIP6/AerChemMIP/CNRM-CERFACS/CNRM-ESM2-1/hist-1950HC/r2i1p1f2/Amon/hus/gr/v20190621/hus_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "type": "inode/symlink",
#                     "title": "hus_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         }
#     ],
#     "links": [
#         {
#             "rel": "self",
#             "href": "https://api.stac.ceda.ac.uk/search?q=aerchemmip&page=1"
#         },
#         {
#             "rel": "next",
#             "href": "https://api.stac.ceda.ac.uk/search?q=aerchemmip&page=2"
#         }
#     ],
#     "context": {
#         "returned": 10,
#         "limit": 10,
#         "matched": 59,
#         "collections": [
#             "Fj3reHsBhuk7QqVbt7P-"
#         ]
#     }
# }
# /Users/kazi.mahir/python-virtual-environments/stac/lib/python3.9/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.stac.ceda.ac.uk'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
result = Client.search(q="AerChem*")
display(result)
# Out:
# {
#     "type": "FeatureCollection",
#     "features": [
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "5ad82e4c683d7dd9865c3849677b135e",
#             "collection": "Fj3reHsBhuk7QqVbt7P-",
#             "bbox": null,
#             "properties": {
#                 "var_id": "ch4",
#                 "table_id": "Amon",
#                 "source_id": "CNRM-ESM2-1",
#                 "experiment_id": "hist-1950HC",
#                 "realization_index": "2",
#                 "initialisation_index": "1",
#                 "physics_index": "1",
#                 "forcing_index": "2",
#                 "grid_label": "gr",
#                 "start_datetime": "1950-01-01T00:00:00",
#                 "end_datetime": "2014-12-01T00:00:00",
#                 "mip_era": "CMIP6",
#                 "activity_id": "AerChemMIP",
#                 "institution_id": "CNRM-CERFACS",
#                 "version": "20190621"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-/items/5ad82e4c683d7dd9865c3849677b135e"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "965a73f1c0f0a51e308183e258d38577": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip6/data/CMIP6/AerChemMIP/CNRM-CERFACS/CNRM-ESM2-1/hist-1950HC/r2i1p1f2/Amon/ch4/gr/v20190621/ch4_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "type": "inode/symlink",
#                     "title": "ch4_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "1ccc129d883d6855bc7a2591b652171e",
#             "collection": "Fj3reHsBhuk7QqVbt7P-",
#             "bbox": null,
#             "properties": {
#                 "var_id": "clivi",
#                 "table_id": "Amon",
#                 "source_id": "CNRM-ESM2-1",
#                 "experiment_id": "hist-1950HC",
#                 "realization_index": "2",
#                 "initialisation_index": "1",
#                 "physics_index": "1",
#                 "forcing_index": "2",
#                 "grid_label": "gr",
#                 "start_datetime": "1950-01-01T00:00:00",
#                 "end_datetime": "2014-12-01T00:00:00",
#                 "mip_era": "CMIP6",
#                 "activity_id": "AerChemMIP",
#                 "institution_id": "CNRM-CERFACS",
#                 "version": "20190621"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-/items/1ccc129d883d6855bc7a2591b652171e"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "ba61ec5fa0731b3ae2df6533bfa056d1": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip6/data/CMIP6/AerChemMIP/CNRM-CERFACS/CNRM-ESM2-1/hist-1950HC/r2i1p1f2/Amon/clivi/gr/v20190621/clivi_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "type": "inode/symlink",
#                     "title": "clivi_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "0d3af2dc6477148ed733ffecc5cf4208",
#             "collection": "Fj3reHsBhuk7QqVbt7P-",
#             "bbox": null,
#             "properties": {
#                 "var_id": "clt",
#                 "table_id": "Amon",
#                 "source_id": "CNRM-ESM2-1",
#                 "experiment_id": "hist-1950HC",
#                 "realization_index": "2",
#                 "initialisation_index": "1",
#                 "physics_index": "1",
#                 "forcing_index": "2",
#                 "grid_label": "gr",
#                 "start_datetime": "1950-01-01T00:00:00",
#                 "end_datetime": "2014-12-01T00:00:00",
#                 "mip_era": "CMIP6",
#                 "activity_id": "AerChemMIP",
#                 "institution_id": "CNRM-CERFACS",
#                 "version": "20190621"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-/items/0d3af2dc6477148ed733ffecc5cf4208"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "8a36e9df8ed59bb74c36857bc149a404": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip6/data/CMIP6/AerChemMIP/CNRM-CERFACS/CNRM-ESM2-1/hist-1950HC/r2i1p1f2/Amon/clt/gr/v20190621/clt_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "type": "inode/symlink",
#                     "title": "clt_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "cecffa1faeaf0e1132a44504ae0b75fe",
#             "collection": "Fj3reHsBhuk7QqVbt7P-",
#             "bbox": null,
#             "properties": {
#                 "var_id": "clwvi",
#                 "table_id": "Amon",
#                 "source_id": "CNRM-ESM2-1",
#                 "experiment_id": "hist-1950HC",
#                 "realization_index": "2",
#                 "initialisation_index": "1",
#                 "physics_index": "1",
#                 "forcing_index": "2",
#                 "grid_label": "gr",
#                 "start_datetime": "1950-01-01T00:00:00",
#                 "end_datetime": "2014-12-01T00:00:00",
#                 "mip_era": "CMIP6",
#                 "activity_id": "AerChemMIP",
#                 "institution_id": "CNRM-CERFACS",
#                 "version": "20190621"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-/items/cecffa1faeaf0e1132a44504ae0b75fe"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "d05760c2ce9dacb2851d5db51e3dc755": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip6/data/CMIP6/AerChemMIP/CNRM-CERFACS/CNRM-ESM2-1/hist-1950HC/r2i1p1f2/Amon/clwvi/gr/v20190621/clwvi_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "type": "inode/symlink",
#                     "title": "clwvi_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "f5925c2077c8803e9685d20ba1444dbb",
#             "collection": "Fj3reHsBhuk7QqVbt7P-",
#             "bbox": null,
#             "properties": {
#                 "var_id": "co2",
#                 "table_id": "Amon",
#                 "source_id": "CNRM-ESM2-1",
#                 "experiment_id": "hist-1950HC",
#                 "realization_index": "2",
#                 "initialisation_index": "1",
#                 "physics_index": "1",
#                 "forcing_index": "2",
#                 "grid_label": "gr",
#                 "start_datetime": "1950-01-01T00:00:00",
#                 "end_datetime": "2014-12-01T00:00:00",
#                 "mip_era": "CMIP6",
#                 "activity_id": "AerChemMIP",
#                 "institution_id": "CNRM-CERFACS",
#                 "version": "20190621"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-/items/f5925c2077c8803e9685d20ba1444dbb"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "45b00a6238653db458aa83bb48c537f7": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip6/data/CMIP6/AerChemMIP/CNRM-CERFACS/CNRM-ESM2-1/hist-1950HC/r2i1p1f2/Amon/co2/gr/v20190621/co2_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "type": "inode/symlink",
#                     "title": "co2_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "6de4996cae53fb86d4e65e0c91f71cde",
#             "collection": "Fj3reHsBhuk7QqVbt7P-",
#             "bbox": null,
#             "properties": {
#                 "var_id": "evspsbl",
#                 "table_id": "Amon",
#                 "source_id": "CNRM-ESM2-1",
#                 "experiment_id": "hist-1950HC",
#                 "realization_index": "2",
#                 "initialisation_index": "1",
#                 "physics_index": "1",
#                 "forcing_index": "2",
#                 "grid_label": "gr",
#                 "start_datetime": "1950-01-01T00:00:00",
#                 "end_datetime": "2014-12-01T00:00:00",
#                 "mip_era": "CMIP6",
#                 "activity_id": "AerChemMIP",
#                 "institution_id": "CNRM-CERFACS",
#                 "version": "20190621"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-/items/6de4996cae53fb86d4e65e0c91f71cde"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "afbaa615a4fae5b51547dd9662033a30": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip6/data/CMIP6/AerChemMIP/CNRM-CERFACS/CNRM-ESM2-1/hist-1950HC/r2i1p1f2/Amon/evspsbl/gr/v20190621/evspsbl_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "type": "inode/symlink",
#                     "title": "evspsbl_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "83dab11f5ad107e5b492bef30efb74d6",
#             "collection": "Fj3reHsBhuk7QqVbt7P-",
#             "bbox": null,
#             "properties": {
#                 "var_id": "hfls",
#                 "table_id": "Amon",
#                 "source_id": "CNRM-ESM2-1",
#                 "experiment_id": "hist-1950HC",
#                 "realization_index": "2",
#                 "initialisation_index": "1",
#                 "physics_index": "1",
#                 "forcing_index": "2",
#                 "grid_label": "gr",
#                 "start_datetime": "1950-01-01T00:00:00",
#                 "end_datetime": "2014-12-01T00:00:00",
#                 "mip_era": "CMIP6",
#                 "activity_id": "AerChemMIP",
#                 "institution_id": "CNRM-CERFACS",
#                 "version": "20190621"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-/items/83dab11f5ad107e5b492bef30efb74d6"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "5b56b01f857bdeb7a1cb60173b981e9c": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip6/data/CMIP6/AerChemMIP/CNRM-CERFACS/CNRM-ESM2-1/hist-1950HC/r2i1p1f2/Amon/hfls/gr/v20190621/hfls_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "type": "inode/symlink",
#                     "title": "hfls_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "7d8a3d47529ec005b3980849aa713310",
#             "collection": "Fj3reHsBhuk7QqVbt7P-",
#             "bbox": null,
#             "properties": {
#                 "var_id": "hfss",
#                 "table_id": "Amon",
#                 "source_id": "CNRM-ESM2-1",
#                 "experiment_id": "hist-1950HC",
#                 "realization_index": "2",
#                 "initialisation_index": "1",
#                 "physics_index": "1",
#                 "forcing_index": "2",
#                 "grid_label": "gr",
#                 "start_datetime": "1950-01-01T00:00:00",
#                 "end_datetime": "2014-12-01T00:00:00",
#                 "mip_era": "CMIP6",
#                 "activity_id": "AerChemMIP",
#                 "institution_id": "CNRM-CERFACS",
#                 "version": "20190621"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-/items/7d8a3d47529ec005b3980849aa713310"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "21d4decca94ba8bb4d79426af52214ce": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip6/data/CMIP6/AerChemMIP/CNRM-CERFACS/CNRM-ESM2-1/hist-1950HC/r2i1p1f2/Amon/hfss/gr/v20190621/hfss_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "type": "inode/symlink",
#                     "title": "hfss_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "5f0fc6847068dfad162018279de5db60",
#             "collection": "Fj3reHsBhuk7QqVbt7P-",
#             "bbox": null,
#             "properties": {
#                 "var_id": "hur",
#                 "table_id": "Amon",
#                 "source_id": "CNRM-ESM2-1",
#                 "experiment_id": "hist-1950HC",
#                 "realization_index": "2",
#                 "initialisation_index": "1",
#                 "physics_index": "1",
#                 "forcing_index": "2",
#                 "grid_label": "gr",
#                 "start_datetime": "1950-01-01T00:00:00",
#                 "end_datetime": "2014-12-01T00:00:00",
#                 "mip_era": "CMIP6",
#                 "activity_id": "AerChemMIP",
#                 "institution_id": "CNRM-CERFACS",
#                 "version": "20190621"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-/items/5f0fc6847068dfad162018279de5db60"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "a3c9aaab33617d52bef17d7a95122f71": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip6/data/CMIP6/AerChemMIP/CNRM-CERFACS/CNRM-ESM2-1/hist-1950HC/r2i1p1f2/Amon/hur/gr/v20190621/hur_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "type": "inode/symlink",
#                     "title": "hur_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "b6e9f223b18cc44acf0ef0d9e75148e1",
#             "collection": "Fj3reHsBhuk7QqVbt7P-",
#             "bbox": null,
#             "properties": {
#                 "var_id": "hus",
#                 "table_id": "Amon",
#                 "source_id": "CNRM-ESM2-1",
#                 "experiment_id": "hist-1950HC",
#                 "realization_index": "2",
#                 "initialisation_index": "1",
#                 "physics_index": "1",
#                 "forcing_index": "2",
#                 "grid_label": "gr",
#                 "start_datetime": "1950-01-01T00:00:00",
#                 "end_datetime": "2014-12-01T00:00:00",
#                 "mip_era": "CMIP6",
#                 "activity_id": "AerChemMIP",
#                 "institution_id": "CNRM-CERFACS",
#                 "version": "20190621"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-/items/b6e9f223b18cc44acf0ef0d9e75148e1"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "25f402f26066de66e79bda2786f534c9": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip6/data/CMIP6/AerChemMIP/CNRM-CERFACS/CNRM-ESM2-1/hist-1950HC/r2i1p1f2/Amon/hus/gr/v20190621/hus_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "type": "inode/symlink",
#                     "title": "hus_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         }
#     ],
#     "links": [
#         {
#             "rel": "self",
#             "href": "https://api.stac.ceda.ac.uk/search?q=AerChem*&page=1"
#         },
#         {
#             "rel": "next",
#             "href": "https://api.stac.ceda.ac.uk/search?q=AerChem*&page=2"
#         }
#     ],
#     "context": {
#         "returned": 10,
#         "limit": 10,
#         "matched": 59,
#         "collections": [
#             "Fj3reHsBhuk7QqVbt7P-"
#         ]
#     }
# }
# /Users/kazi.mahir/python-virtual-environments/stac/lib/python3.9/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.stac.ceda.ac.uk'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %% [markdown]
# ### Facet Search
# Filter the search result based on facets of an item. The facet request body
# should use a dictionary with valid facets found with queryables, labeled under
# the filter argument.
#
# Facet search is provided by this STAC extension:
#
# - https://api.stacspec.org/v1.0.0-beta.3/item-search/#operation/postItemSearch

# %%
# The filter is the label for facet search where it consists of a dictionary
# made up of the facet as the key and value what to filter for.
# Just like others, it can be queried with other arguments:
result = Client.search(
    q="AerChem*",
    filter={
     "eq": [
         {"property": "institution_id"},
         "CNRM-CERFACS"
     ]
  }
)
display(result)
# Out:
# {
#     "type": "FeatureCollection",
#     "features": [
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "5ad82e4c683d7dd9865c3849677b135e",
#             "collection": "Fj3reHsBhuk7QqVbt7P-",
#             "bbox": null,
#             "properties": {
#                 "var_id": "ch4",
#                 "table_id": "Amon",
#                 "source_id": "CNRM-ESM2-1",
#                 "experiment_id": "hist-1950HC",
#                 "realization_index": "2",
#                 "initialisation_index": "1",
#                 "physics_index": "1",
#                 "forcing_index": "2",
#                 "grid_label": "gr",
#                 "start_datetime": "1950-01-01T00:00:00",
#                 "end_datetime": "2014-12-01T00:00:00",
#                 "mip_era": "CMIP6",
#                 "activity_id": "AerChemMIP",
#                 "institution_id": "CNRM-CERFACS",
#                 "version": "20190621"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-/items/5ad82e4c683d7dd9865c3849677b135e"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "965a73f1c0f0a51e308183e258d38577": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip6/data/CMIP6/AerChemMIP/CNRM-CERFACS/CNRM-ESM2-1/hist-1950HC/r2i1p1f2/Amon/ch4/gr/v20190621/ch4_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "type": "inode/symlink",
#                     "title": "ch4_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "1ccc129d883d6855bc7a2591b652171e",
#             "collection": "Fj3reHsBhuk7QqVbt7P-",
#             "bbox": null,
#             "properties": {
#                 "var_id": "clivi",
#                 "table_id": "Amon",
#                 "source_id": "CNRM-ESM2-1",
#                 "experiment_id": "hist-1950HC",
#                 "realization_index": "2",
#                 "initialisation_index": "1",
#                 "physics_index": "1",
#                 "forcing_index": "2",
#                 "grid_label": "gr",
#                 "start_datetime": "1950-01-01T00:00:00",
#                 "end_datetime": "2014-12-01T00:00:00",
#                 "mip_era": "CMIP6",
#                 "activity_id": "AerChemMIP",
#                 "institution_id": "CNRM-CERFACS",
#                 "version": "20190621"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-/items/1ccc129d883d6855bc7a2591b652171e"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "ba61ec5fa0731b3ae2df6533bfa056d1": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip6/data/CMIP6/AerChemMIP/CNRM-CERFACS/CNRM-ESM2-1/hist-1950HC/r2i1p1f2/Amon/clivi/gr/v20190621/clivi_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "type": "inode/symlink",
#                     "title": "clivi_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "0d3af2dc6477148ed733ffecc5cf4208",
#             "collection": "Fj3reHsBhuk7QqVbt7P-",
#             "bbox": null,
#             "properties": {
#                 "var_id": "clt",
#                 "table_id": "Amon",
#                 "source_id": "CNRM-ESM2-1",
#                 "experiment_id": "hist-1950HC",
#                 "realization_index": "2",
#                 "initialisation_index": "1",
#                 "physics_index": "1",
#                 "forcing_index": "2",
#                 "grid_label": "gr",
#                 "start_datetime": "1950-01-01T00:00:00",
#                 "end_datetime": "2014-12-01T00:00:00",
#                 "mip_era": "CMIP6",
#                 "activity_id": "AerChemMIP",
#                 "institution_id": "CNRM-CERFACS",
#                 "version": "20190621"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-/items/0d3af2dc6477148ed733ffecc5cf4208"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "8a36e9df8ed59bb74c36857bc149a404": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip6/data/CMIP6/AerChemMIP/CNRM-CERFACS/CNRM-ESM2-1/hist-1950HC/r2i1p1f2/Amon/clt/gr/v20190621/clt_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "type": "inode/symlink",
#                     "title": "clt_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "cecffa1faeaf0e1132a44504ae0b75fe",
#             "collection": "Fj3reHsBhuk7QqVbt7P-",
#             "bbox": null,
#             "properties": {
#                 "var_id": "clwvi",
#                 "table_id": "Amon",
#                 "source_id": "CNRM-ESM2-1",
#                 "experiment_id": "hist-1950HC",
#                 "realization_index": "2",
#                 "initialisation_index": "1",
#                 "physics_index": "1",
#                 "forcing_index": "2",
#                 "grid_label": "gr",
#                 "start_datetime": "1950-01-01T00:00:00",
#                 "end_datetime": "2014-12-01T00:00:00",
#                 "mip_era": "CMIP6",
#                 "activity_id": "AerChemMIP",
#                 "institution_id": "CNRM-CERFACS",
#                 "version": "20190621"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-/items/cecffa1faeaf0e1132a44504ae0b75fe"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "d05760c2ce9dacb2851d5db51e3dc755": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip6/data/CMIP6/AerChemMIP/CNRM-CERFACS/CNRM-ESM2-1/hist-1950HC/r2i1p1f2/Amon/clwvi/gr/v20190621/clwvi_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "type": "inode/symlink",
#                     "title": "clwvi_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "f5925c2077c8803e9685d20ba1444dbb",
#             "collection": "Fj3reHsBhuk7QqVbt7P-",
#             "bbox": null,
#             "properties": {
#                 "var_id": "co2",
#                 "table_id": "Amon",
#                 "source_id": "CNRM-ESM2-1",
#                 "experiment_id": "hist-1950HC",
#                 "realization_index": "2",
#                 "initialisation_index": "1",
#                 "physics_index": "1",
#                 "forcing_index": "2",
#                 "grid_label": "gr",
#                 "start_datetime": "1950-01-01T00:00:00",
#                 "end_datetime": "2014-12-01T00:00:00",
#                 "mip_era": "CMIP6",
#                 "activity_id": "AerChemMIP",
#                 "institution_id": "CNRM-CERFACS",
#                 "version": "20190621"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-/items/f5925c2077c8803e9685d20ba1444dbb"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "45b00a6238653db458aa83bb48c537f7": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip6/data/CMIP6/AerChemMIP/CNRM-CERFACS/CNRM-ESM2-1/hist-1950HC/r2i1p1f2/Amon/co2/gr/v20190621/co2_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "type": "inode/symlink",
#                     "title": "co2_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "6de4996cae53fb86d4e65e0c91f71cde",
#             "collection": "Fj3reHsBhuk7QqVbt7P-",
#             "bbox": null,
#             "properties": {
#                 "var_id": "evspsbl",
#                 "table_id": "Amon",
#                 "source_id": "CNRM-ESM2-1",
#                 "experiment_id": "hist-1950HC",
#                 "realization_index": "2",
#                 "initialisation_index": "1",
#                 "physics_index": "1",
#                 "forcing_index": "2",
#                 "grid_label": "gr",
#                 "start_datetime": "1950-01-01T00:00:00",
#                 "end_datetime": "2014-12-01T00:00:00",
#                 "mip_era": "CMIP6",
#                 "activity_id": "AerChemMIP",
#                 "institution_id": "CNRM-CERFACS",
#                 "version": "20190621"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-/items/6de4996cae53fb86d4e65e0c91f71cde"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "afbaa615a4fae5b51547dd9662033a30": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip6/data/CMIP6/AerChemMIP/CNRM-CERFACS/CNRM-ESM2-1/hist-1950HC/r2i1p1f2/Amon/evspsbl/gr/v20190621/evspsbl_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "type": "inode/symlink",
#                     "title": "evspsbl_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "83dab11f5ad107e5b492bef30efb74d6",
#             "collection": "Fj3reHsBhuk7QqVbt7P-",
#             "bbox": null,
#             "properties": {
#                 "var_id": "hfls",
#                 "table_id": "Amon",
#                 "source_id": "CNRM-ESM2-1",
#                 "experiment_id": "hist-1950HC",
#                 "realization_index": "2",
#                 "initialisation_index": "1",
#                 "physics_index": "1",
#                 "forcing_index": "2",
#                 "grid_label": "gr",
#                 "start_datetime": "1950-01-01T00:00:00",
#                 "end_datetime": "2014-12-01T00:00:00",
#                 "mip_era": "CMIP6",
#                 "activity_id": "AerChemMIP",
#                 "institution_id": "CNRM-CERFACS",
#                 "version": "20190621"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-/items/83dab11f5ad107e5b492bef30efb74d6"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "5b56b01f857bdeb7a1cb60173b981e9c": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip6/data/CMIP6/AerChemMIP/CNRM-CERFACS/CNRM-ESM2-1/hist-1950HC/r2i1p1f2/Amon/hfls/gr/v20190621/hfls_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "type": "inode/symlink",
#                     "title": "hfls_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "7d8a3d47529ec005b3980849aa713310",
#             "collection": "Fj3reHsBhuk7QqVbt7P-",
#             "bbox": null,
#             "properties": {
#                 "var_id": "hfss",
#                 "table_id": "Amon",
#                 "source_id": "CNRM-ESM2-1",
#                 "experiment_id": "hist-1950HC",
#                 "realization_index": "2",
#                 "initialisation_index": "1",
#                 "physics_index": "1",
#                 "forcing_index": "2",
#                 "grid_label": "gr",
#                 "start_datetime": "1950-01-01T00:00:00",
#                 "end_datetime": "2014-12-01T00:00:00",
#                 "mip_era": "CMIP6",
#                 "activity_id": "AerChemMIP",
#                 "institution_id": "CNRM-CERFACS",
#                 "version": "20190621"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-/items/7d8a3d47529ec005b3980849aa713310"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "21d4decca94ba8bb4d79426af52214ce": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip6/data/CMIP6/AerChemMIP/CNRM-CERFACS/CNRM-ESM2-1/hist-1950HC/r2i1p1f2/Amon/hfss/gr/v20190621/hfss_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "type": "inode/symlink",
#                     "title": "hfss_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "5f0fc6847068dfad162018279de5db60",
#             "collection": "Fj3reHsBhuk7QqVbt7P-",
#             "bbox": null,
#             "properties": {
#                 "var_id": "hur",
#                 "table_id": "Amon",
#                 "source_id": "CNRM-ESM2-1",
#                 "experiment_id": "hist-1950HC",
#                 "realization_index": "2",
#                 "initialisation_index": "1",
#                 "physics_index": "1",
#                 "forcing_index": "2",
#                 "grid_label": "gr",
#                 "start_datetime": "1950-01-01T00:00:00",
#                 "end_datetime": "2014-12-01T00:00:00",
#                 "mip_era": "CMIP6",
#                 "activity_id": "AerChemMIP",
#                 "institution_id": "CNRM-CERFACS",
#                 "version": "20190621"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-/items/5f0fc6847068dfad162018279de5db60"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "a3c9aaab33617d52bef17d7a95122f71": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip6/data/CMIP6/AerChemMIP/CNRM-CERFACS/CNRM-ESM2-1/hist-1950HC/r2i1p1f2/Amon/hur/gr/v20190621/hur_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "type": "inode/symlink",
#                     "title": "hur_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "stac_version": "1.0.0",
#             "stac_extensions": [],
#             "id": "b6e9f223b18cc44acf0ef0d9e75148e1",
#             "collection": "Fj3reHsBhuk7QqVbt7P-",
#             "bbox": null,
#             "properties": {
#                 "var_id": "hus",
#                 "table_id": "Amon",
#                 "source_id": "CNRM-ESM2-1",
#                 "experiment_id": "hist-1950HC",
#                 "realization_index": "2",
#                 "initialisation_index": "1",
#                 "physics_index": "1",
#                 "forcing_index": "2",
#                 "grid_label": "gr",
#                 "start_datetime": "1950-01-01T00:00:00",
#                 "end_datetime": "2014-12-01T00:00:00",
#                 "mip_era": "CMIP6",
#                 "activity_id": "AerChemMIP",
#                 "institution_id": "CNRM-CERFACS",
#                 "version": "20190621"
#             },
#             "links": [
#                 {
#                     "rel": "self",
#                     "type": "application/geo+json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-/items/b6e9f223b18cc44acf0ef0d9e75148e1"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/collections/Fj3reHsBhuk7QqVbt7P-"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
#                     "href": "https://api.stac.ceda.ac.uk/"
#                 }
#             ],
#             "assets": {
#                 "25f402f26066de66e79bda2786f534c9": {
#                     "href": "https://dap.ceda.ac.uk/badc/cmip6/data/CMIP6/AerChemMIP/CNRM-CERFACS/CNRM-ESM2-1/hist-1950HC/r2i1p1f2/Amon/hus/gr/v20190621/hus_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "type": "inode/symlink",
#                     "title": "hus_Amon_CNRM-ESM2-1_hist-1950HC_r2i1p1f2_gr_195001-201412.nc",
#                     "roles": [
#                         "data"
#                     ]
#                 }
#             }
#         }
#     ],
#     "links": [
#         {
#             "rel": "self",
#             "href": "https://api.stac.ceda.ac.uk/search?page=1"
#         },
#         {
#             "rel": "next",
#             "href": "https://api.stac.ceda.ac.uk/search?page=2"
#         }
#     ],
#     "context": {
#         "returned": 10,
#         "limit": 10,
#         "matched": 59,
#         "collections": [
#             "Fj3reHsBhuk7QqVbt7P-"
#         ]
#     }
# }
# /Users/kazi.mahir/python-virtual-environments/stac/lib/python3.9/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.stac.ceda.ac.uk'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
